# %%
import pandas as pd
import geopandas as gpd
import re

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
month = "August"

# %% [markdown]
# # Reading In Rental List - Magnum and R&R

# %%
#R&R and Magnum Rental List
RRList = pd.read_excel("BLM Rents {} 2020.xlsx".format(month), header = 4, usecols = 8)
MPLPList = pd.read_excel("BLM Rents {} 2020.xlsx".format(month), header = 4, usecols = 8, sheet_name = "MPLP")
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/io/excel.py:527: FutureWarning: Passing in an integer for `usecols` has been deprecated. Please pass in a list of int from 0 to `usecols` inclusive instead.
#   usecols = _maybe_convert_usecols(usecols)

# %%
#Reading Mastr shapefile
shapefile = gpd.read_file("zip://Master Shapefile 7-7-20.zip")
shapefile.columns
# Out:
# Index(['OBJECTID', 'LEASE_NO', 'EFFECTIVE', 'COUNTY', 'ST', 'Ownership',
#        'GeneralLoc', 'Due_Year', 'Acres', 'COMMENTS', 'Est_Bonus', 'Exp_date',
#        'geometry'],
#       dtype='object')

# %%
RRList
MPLPList
# Out:
#       LEASE NO.               COUNTY      STATE EXPIRATION    ACRES  RENTAL  \
# 0     LAES57452  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  1998.57  3998.0
# 1     LAES57453  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   638.47  1278.0
# 2     LAES57454  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   636.63  1274.0
# 3     LAES57455  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  1154.67  2310.0
# 4     LAES57456  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   636.32  1274.0
# 5     LAES57457  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   636.72  1274.0
# 6     LAES57458  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   636.68  1274.0
# 7     LAES57459  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  2022.78  4046.0
# 8     LAES57460  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   636.68  1274.0
# 9     LAES57461  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  1273.80  2548.0
# 10    LAES57462  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   637.40  1276.0
# 11    LAES57463  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   636.52  1274.0
# 12    LAES57464  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   591.10  1184.0
# 13    LAES57465  NATCHITOCHES PARISH  LOUISIANA 2022-08-01   637.76  1276.0
# 14    LAES57466  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  1274.00  2548.0
# 15    LAES57467  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  2054.08  4110.0
# 16    LAES57468  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  1911.48  3824.0
# 17    LAES57469  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  1588.40  3178.0
# 18    LAES57470  NATCHITOCHES PARISH  LOUISIANA 2022-08-01  2498.37  4998.0
# 19    LAES57471  NATCHITOCHES PARISH  LOUISIANA 2022-08-01    89.10   180.0
# 20          NaN                  NaN        NaN        NaT      NaN     NaN
# 21   LAES056818          WINN PARISH  LOUISIANA 2021-08-01    39.55    80.0
# 22   LAES056819          WINN PARISH  LOUISIANA 2021-08-01   377.03   756.0
# 23   LAES056820          WINN PARISH  LOUISIANA 2021-08-01   757.41  1516.0
# 24   LAES056821          WINN PARISH  LOUISIANA 2021-08-01   715.99  1432.0
# 25   LAES056822          WINN PARISH  LOUISIANA 2021-08-01  1613.27  3228.0
# 26   LAES056823          WINN PARISH  LOUISIANA 2021-08-01   242.37   486.0
# 27   LAES056828          WINN PARISH  LOUISIANA 2021-08-01    79.64   160.0
# 28   LAES056829          WINN PARISH  LOUISIANA 2021-08-01    79.66   160.0
# 29   LAES056831          WINN PARISH  LOUISIANA 2021-08-01   279.78   560.0
# ..          ...                  ...        ...        ...      ...     ...
# 160         NaN                  NaN        NaN        NaT      NaN     NaN
# 161         NaN                  NaN        NaN        NaT      NaN     NaN
# 162         NaN                  NaN        NaN        NaT      NaN     NaN
# 163         NaN                  NaN        NaN        NaT      NaN     NaN
# 164         NaN                  NaN        NaN        NaT      NaN     NaN
# 165         NaN                  NaN        NaN        NaT      NaN     NaN
# 166         NaN                  NaN        NaN        NaT      NaN     NaN
# 167         NaN                  NaN        NaN        NaT      NaN     NaN
# 168         NaN                  NaN        NaN        NaT      NaN     NaN
# 169         NaN                  NaN        NaN        NaT      NaN     NaN
# 170         NaN                  NaN        NaN        NaT      NaN     NaN
# 171         NaN                  NaN        NaN        NaT      NaN     NaN
# 172         NaN                  NaN        NaN        NaT      NaN     NaN
# 173         NaN                  NaN        NaN        NaT      NaN     NaN
# 174         NaN                  NaN        NaN        NaT      NaN     NaN
# 175         NaN                  NaN        NaN        NaT      NaN     NaN
# 176         NaN                  NaN        NaN        NaT      NaN     NaN
# 177         NaN                  NaN        NaN        NaT      NaN     NaN
# 178         NaN                  NaN        NaN        NaT      NaN     NaN
# 179         NaN                  NaN        NaN        NaT      NaN     NaN
# 180         NaN                  NaN        NaN        NaT      NaN     NaN
# 181         NaN                  NaN        NaN        NaT      NaN     NaN
# 182         NaN                  NaN        NaN        NaT      NaN     NaN
# 183         NaN                  NaN        NaN        NaT      NaN     NaN
# 184         NaN                  NaN        NaN        NaT      NaN     NaN
# 185         NaN                  NaN        NaN        NaT      NaN     NaN
# 186         NaN                  NaN        NaN        NaT      NaN     NaN
# 187         NaN                  NaN        NaN        NaT      NaN     NaN
# 188         NaN                  NaN        NaN        NaT      NaN     NaN
# 189         NaN                  NaN        NaN        NaT      NaN     NaN
#
#      COUNTY.1  Y/N   Unnamed: 8
# 0         NaN  NaN          NaN
# 1         NaN  NaN          NaN
# 2         NaN  NaN          NaN
# 3         NaN  NaN          NaN
# 4         NaN  NaN          NaN
# 5         NaN  NaN          NaN
# 6         NaN  NaN          NaN
# 7         NaN  NaN          NaN
# 8         NaN  NaN          NaN
# 9         NaN  NaN          NaN
# 10        NaN  NaN          NaN
# 11        NaN  NaN          NaN
# 12        NaN  NaN          NaN
# 13        NaN  NaN          NaN
# 14        NaN  NaN          NaN
# 15        NaN  NaN          NaN
# 16        NaN  NaN          NaN
# 17        NaN  NaN          NaN
# 18        NaN  NaN          NaN
# 19    44398.0  NaN          NaN
# 20        NaN  NaN          NaN
# 21        NaN  NaN          NaN
# 22        NaN  NaN          NaN
# 23        NaN  NaN          NaN
# 24        NaN  NaN          NaN
# 25        NaN  NaN          NaN
# 26        NaN  NaN          NaN
# 27        NaN  NaN          NaN
# 28        NaN  NaN          NaN
# 29        NaN  NaN          NaN
# ..        ...  ...          ...
# 160       NaN  NaN          NaN
# 161       NaN  NaN          NaN
# 162       NaN  NaN          NaN
# 163       NaN  NaN          NaN
# 164       NaN  NaN          NaN
# 165       NaN  NaN          NaN
# 166       NaN  NaN          NaN
# 167       NaN  NaN          NaN
# 168       NaN  NaN          NaN
# 169       NaN  NaN          NaN
# 170       NaN  NaN          NaN
# 171       NaN  NaN          NaN
# 172       NaN  NaN          NaN
# 173       NaN  NaN          NaN
# 174       NaN  NaN          NaN
# 175       NaN  NaN          NaN
# 176       NaN  NaN          NaN
# 177       NaN  NaN          NaN
# 178       NaN  NaN          NaN
# 179       NaN  NaN          NaN
# 180       NaN  NaN          NaN
# 181       NaN  NaN          NaN
# 182       NaN  NaN          NaN
# 183       NaN  NaN          NaN
# 184       NaN  NaN          NaN
# 185       NaN  NaN          NaN
# 186       NaN  NaN          NaN
# 187       NaN  NaN          NaN
# 188       NaN  NaN          NaN
# 189       NaN  NaN  <-RECONCILE
#
# [190 rows x 9 columns]
#      LEASE NO.      COUNTY         STATE EXPIRATION    ACRES   RENTAL  \
# 0   ARES059276    CLEBURNE      ARKANSAS 2028-08-01   205.00    307.5
# 1   ARES059277    CLEBURNE      ARKANSAS 2028-08-01   120.00    180.0
# 2   ARES059278    CLEBURNE      ARKANSAS 2028-08-01    40.00     60.0
# 3   ARES059293    CLEBURNE      ARKANSAS 2028-08-01    86.03    130.5
# 4          NaN         NaN           NaN        NaT      NaN      NaN
# 5   ARES059280   VAN BUREN      ARKANSAS 2028-08-01    39.80     60.0
# 6   ARES059281   VAN BUREN      ARKANSAS 2028-08-01    80.00    120.0
# 7   ARES059282   VAN BUREN      ARKANSAS 2028-08-01   364.38    547.5
# 8   ARES059283   VAN BUREN      ARKANSAS 2028-08-01   122.38    184.5
# 9   ARES059285   VAN BUREN      ARKANSAS 2028-08-01    40.00     60.0
# 10  ARES059286   VAN BUREN      ARKANSAS 2028-08-01    67.50    102.0
# 11  ARES059287   VAN BUREN      ARKANSAS 2028-08-01    40.00     60.0
# 12  ARES059288   VAN BUREN      ARKANSAS 2028-08-01    40.00     60.0
# 13  ARES059289   VAN BUREN      ARKANSAS 2028-08-01    80.00    120.0
# 14  ARES059290   VAN BUREN      ARKANSAS 2028-08-01   120.00    180.0
# 15  ARES059291   VAN BUREN      ARKANSAS 2028-08-01    80.00    120.0
# 16  ARES059292   VAN BUREN      ARKANSAS 2028-08-01    40.00     60.0
# 17  ARES059299   VAN BUREN      ARKANSAS 2028-08-01    39.59     60.0
# 18         NaN         NaN           NaN        NaT      NaN      NaN
# 19    COC78348  RIO BLANCO      COLORADO 2027-08-01  1787.82   2682.0
# 20    COC78349  RIO BLANCO      COLORADO 2027-08-01  1808.82   2713.5
# 21    COC78350  RIO BLANCO      COLORADO 2027-08-01  1873.26   2811.0
# 22    COC78351  RIO BLANCO      COLORADO 2027-08-01  1917.52   2877.0
# 23    COC78352  RIO BLANCO      COLORADO 2027-08-01  1914.96   2872.5
# 24    COC78353  RIO BLANCO      COLORADO 2027-08-01  1834.59   2752.5
# 25    COC78355  RIO BLANCO      COLORADO 2027-08-01   640.00    960.0
# 26    COC78356  RIO BLANCO      COLORADO 2027-08-01  1440.00   2160.0
# 27    COC78357  RIO BLANCO      COLORADO 2027-08-01  2230.00   3345.0
# 28    COC78358  RIO BLANCO      COLORADO 2027-08-01  1920.40   2881.5
# 29    COC78359  RIO BLANCO      COLORADO 2027-08-01  2164.84   3247.5
# ..         ...         ...           ...        ...      ...      ...
# 52  MSES056949    HARRISON   MISSISSIPPI 2021-08-01   359.33    720.0
# 53  MSES056950    HARRISON   MISSISSIPPI 2021-08-01   399.53    800.0
# 54  MSES056951    HARRISON   MISSISSIPPI 2021-08-01  1236.33   2474.0
# 55  MSES056955    HARRISON   MISSISSIPPI 2021-08-01  1278.00   2556.0
# 56  MSES056956    HARRISON   MISSISSIPPI 2021-08-01  1277.40   2556.0
# 57  MSES056960    HARRISON   MISSISSIPPI 2021-08-01  1101.65   2204.0
# 58  MSES056961    HARRISON   MISSISSIPPI 2021-08-01   635.05   1272.0
# 59         NaN         NaN           NaN        NaT      NaN      NaN
# 60  MSES056947     JACKSON   MISSISSIPPI 2021-08-01   640.00   1280.0
# 61  MSES056948     JACKSON   MISSISSIPPI 2021-08-01   537.44   1076.0
# 62  MSES056952     JACKSON   MISSISSIPPI 2021-08-01  1154.53   2310.0
# 63  MSES056953     JACKSON   MISSISSIPPI 2021-08-01   804.76   1610.0
# 64  MSES056954     JACKSON   MISSISSIPPI 2021-08-01   957.28   1916.0
# 65  MSES056958     JACKSON   MISSISSIPPI 2021-08-01  1002.97   2006.0
# 66  MSES056962     JACKSON   MISSISSIPPI 2021-08-01   993.08   1988.0
# 67  MSES056957    JACKSON    MISSISSIPPI 2021-08-01  1324.52   2650.0
# 68  MSES056959    JACKSON    MISSISSIPPI 2021-08-01   834.25   1670.0
# 69         NaN         NaN           NaN        NaT      NaN      NaN
# 70   NDM101479    MCKENZIE  NORTH DAKOTA 2021-08-01   120.69    242.0
# 71         NaN         NaN           NaN        NaT      NaN      NaN
# 72    UTU92328     SANPETE          UTAH 2027-08-01  1239.20   1860.0
# 73    UTU92330     SANPETE          UTAH 2027-08-01  1300.17   1951.5
# 74         NaN         NaN           NaN        NaT      NaN      NaN
# 75    UTU92311      SEVIER          UTAH 2027-08-01   200.00    300.0
# 76    UTU92312      SEVIER          UTAH 2027-08-01   346.74    520.5
# 77    UTU92313      SEVIER          UTAH 2027-08-01   200.00    300.0
# 78    UTU92314      SEVIER          UTAH 2027-08-01  1482.76   2224.5
# 79    UTU92315      SEVIER          UTAH 2027-08-01  2032.52   3049.5
# 80    UTU92316      SEVIER          UTAH 2027-08-01   677.60   1017.0
# 81         NaN         NaN           NaN        NaT      NaN  97849.0
#
#     COUNTY.1  Y/N  Unnamed: 8
# 0        NaN  NaN         NaN
# 1        NaN  NaN         NaN
# 2        NaN  NaN         NaN
# 3      678.0  NaN         NaN
# 4        NaN  NaN         NaN
# 5        NaN  NaN         NaN
# 6        NaN  NaN         NaN
# 7        NaN  NaN         NaN
# 8        NaN  NaN         NaN
# 9        NaN  NaN         NaN
# 10       NaN  NaN         NaN
# 11       NaN  NaN         NaN
# 12       NaN  NaN         NaN
# 13       NaN  NaN         NaN
# 14       NaN  NaN         NaN
# 15       NaN  NaN         NaN
# 16       NaN  NaN         NaN
# 17    1734.0  NaN         NaN
# 18       NaN  NaN         NaN
# 19       NaN  NaN         NaN
# 20       NaN  NaN         NaN
# 21       NaN  NaN         NaN
# 22       NaN  NaN         NaN
# 23       NaN  NaN         NaN
# 24       NaN  NaN         NaN
# 25       NaN  NaN         NaN
# 26       NaN  NaN         NaN
# 27       NaN  NaN         NaN
# 28       NaN  NaN         NaN
# 29       NaN  NaN         NaN
# ..       ...  ...         ...
# 52       NaN  NaN         NaN
# 53       NaN  NaN         NaN
# 54       NaN  NaN         NaN
# 55       NaN  NaN         NaN
# 56       NaN  NaN         NaN
# 57       NaN  NaN         NaN
# 58   12582.0  NaN         NaN
# 59       NaN  NaN         NaN
# 60       NaN  NaN         NaN
# 61       NaN  NaN         NaN
# 62       NaN  NaN         NaN
# 63       NaN  NaN         NaN
# 64       NaN  NaN         NaN
# 65       NaN  NaN         NaN
# 66       NaN  NaN         NaN
# 67       NaN  NaN         NaN
# 68   16506.0  NaN         NaN
# 69       NaN  NaN         NaN
# 70     242.0  NaN         NaN
# 71       NaN  NaN         NaN
# 72       NaN  NaN         NaN
# 73    3811.5  NaN         NaN
# 74       NaN  NaN         NaN
# 75       NaN  NaN         NaN
# 76       NaN  NaN         NaN
# 77       NaN  NaN         NaN
# 78       NaN  NaN         NaN
# 79       NaN  NaN         NaN
# 80    7411.5  NaN         NaN
# 81   97849.0  NaN         NaN
#
# [82 rows x 9 columns]

# %% [markdown]
# ## Concatenating Magnum and RR Into 1 Dataframe
# ### Cleaning Dataframe by removing null rows, subtotal rows, etc

# %%
#concat magnum and r&r rental list
RentalList = pd.concat([RRList, MPLPList])

# %%
#dropping rows with null values for lease number and county
RentalList.dropna(subset = ["LEASE NO.", "COUNTY"], how = 'all', inplace = True)

#resetting index
RentalList.reset_index(inplace = True, drop = True)

RentalList
# Out:
#      LEASE NO.        COUNTY       STATE EXPIRATION    ACRES  RENTAL  \
# 0    MTM110982        BLAINE     MONTANA 2029-07-01    40.00    60.0
# 1    MTM110983        BLAINE     MONTANA 2029-07-01    80.00   120.0
# 2    MTM110985        BLAINE     MONTANA 2029-07-01   430.50   646.5
# 3    MTM111016        DAWSON     MONTANA 2029-07-01   160.00   240.0
# 4    MTM111017        DAWSON     MONTANA 2029-07-01   480.00   720.0
# 5    MTM111022        DAWSON     MONTANA 2029-07-01  2080.00  3120.0
# 6    MTM110971   MUSSELSHELL     MONTANA 2029-07-01   338.59   508.5
# 7    MTM110972   MUSSELSHELL     MONTANA 2029-07-01   770.53  1156.5
# 8    MTM110973   MUSSELSHELL     MONTANA 2029-07-01   240.00   360.0
# 9    MTM110974   MUSSELSHELL     MONTANA 2029-07-01  1124.09  1687.5
# 10   MTM110975   MUSSELSHELL     MONTANA 2029-07-01   327.08   492.0
# 11   MTM110986         TOOLE     MONTANA 2029-07-01   240.92   361.5
# 12  NMNM128371    RIO ARRIBA  NEW MEXICO 2022-07-01   480.00   960.0
# 13  NMNM128376    RIO ARRIBA  NEW MEXICO 2022-07-01   160.00   320.0
# 14  OKNM128387        GARVIN    OKLAHOMA 2022-07-01    20.00    40.0
# 15   MTM101460        DAWSON     MONTANA 2021-07-01  1193.80  2388.0
# 16   MTM101461        DAWSON     MONTANA 2021-07-01   920.00  1840.0
# 17   MTM101462        DAWSON     MONTANA 2021-07-01   864.95  1730.0
# 18   MTM101463        DAWSON     MONTANA 2021-07-01   803.90  1608.0
# 19   MTM101464        DAWSON     MONTANA 2021-07-01   320.00   640.0
# 20   MTM101465        DAWSON     MONTANA 2021-07-01   318.07   638.0
# 21   MTM101471        DAWSON     MONTANA 2021-07-01  1600.00  3200.0
# 22   MTM109323        FALLON     MONTANA 2027-07-01   160.00   240.0
# 23   MTM109324        FALLON     MONTANA 2027-07-01   120.00   180.0
# 24   MTM109325        FALLON     MONTANA 2027-07-01   160.00   240.0
# 25   MTM109326        FALLON     MONTANA 2027-07-01   280.00   420.0
# 26   MTM109327        FALLON     MONTANA 2027-07-01    40.00    60.0
# 27   MTM109328        FALLON     MONTANA 2027-07-01   200.00   300.0
# 28   MTM109204      GARFIELD     MONTANA 2027-07-01   360.00   540.0
# 29   MTM109205      GARFIELD     MONTANA 2027-07-01   240.00   360.0
# 30   MTM109206      GARFIELD     MONTANA 2027-07-01   600.00   900.0
# 31   MTM109207      GARFIELD     MONTANA 2027-07-01   120.00   180.0
# 32   MTM101475  POWDER RIVER     MONTANA 2021-07-01   960.00  1920.0
# 33   MTM101477  POWDER RIVER     MONTANA 2021-07-01  1049.60  2100.0
# 34   MTM109357  POWDER RIVER     MONTANA 2021-07-01   280.33   421.5
# 35   MTM109359  POWDER RIVER     MONTANA 2021-07-01   600.00   900.0
# 36   MTM101455      RICHLAND     MONTANA 2021-07-01    10.32    22.0
# 37   MTM101456      RICHLAND     MONTANA 2021-07-01     5.88    12.0
# 38   MTM101458      RICHLAND     MONTANA 2021-07-01    40.00    80.0
# 39   MTM101466      RICHLAND     MONTANA 2021-07-01   245.38   492.0
#
#     COUNTY.1  Y/N                                   Mishaun Comments
# 0        NaN  NaN                            Keep: 9 years remaining
# 1        NaN  NaN                            Keep: 9 years remaining
# 2      826.5  NaN                            Keep: 9 years remaining
# 3        NaN  NaN                            Keep: 9 years remaining
# 4        NaN  NaN                            Keep: 9 years remaining
# 5     4080.0  NaN                            Keep: 9 years remaining
# 6        NaN  NaN                            Keep: 9 years remaining
# 7        NaN  NaN                            Keep: 9 years remaining
# 8        NaN  NaN                            Keep: 9 years remaining
# 9        NaN  NaN                            Keep: 9 years remaining
# 10    4204.5  NaN                            Keep: 9 years remaining
# 11     361.5  NaN                            Keep: 9 years remaining
# 12       NaN  NaN  Maybe Let Go: No new produciton activity wihti...
# 13    1280.0  NaN  Maybe Let Go: No new produciton activity wihti...
# 14      40.0  NaN  Keep: negligible rental cost - 12 milrs away f...
# 15       NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 16       NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 17       NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 18       NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 19       NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 20       NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 21   12044.0  NaN       Maybe Let Go - east of primary fuels acreage
# 22       NaN  NaN                            Keep: 7 years remaining
# 23       NaN  NaN                            Keep: 7 years remaining
# 24       NaN  NaN                            Keep: 7 years remaining
# 25       NaN  NaN                            Keep: 7 years remaining
# 26       NaN  NaN                            Keep: 7 years remaining
# 27    1440.0  NaN                            Keep: 7 years remaining
# 28       NaN  NaN                            Keep: 7 years remaining
# 29       NaN  NaN                            Keep: 7 years remaining
# 30       NaN  NaN                            Keep: 7 years remaining
# 31    1980.0  NaN                            Keep: 7 years remaining
# 32       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 33       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 34       NaN  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 35    5341.5  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 36       NaN  NaN  Keep: negligible rental - wells around tract h...
# 37       NaN  NaN  Keep: negligible rental - closeset well near t...
# 38       NaN  NaN   Keep: neglgible rental - no activiity near tract
# 39     606.0  NaN  Maybe Let Go: Latest well to be drilled is 201...

# %%
#storing serial numbers found in RentalLis
SerialNumbers = RentalList.loc[:,"LEASE NO."]

SerialNumbers.dropna(inplace = True)

SerialNumbers
# Out:
# 0      MTM110982
# 1      MTM110983
# 2      MTM110985
# 4      MTM111016
# 5      MTM111017
# 6      MTM111022
# 8      MTM110971
# 9      MTM110972
# 10     MTM110973
# 11     MTM110974
# 12     MTM110975
# 14     MTM110986
# 16    NMNM128371
# 17    NMNM128376
# 19    OKNM128387
# 0      MTM101460
# 1      MTM101461
# 2      MTM101462
# 3      MTM101463
# 4      MTM101464
# 5      MTM101465
# 6      MTM101471
# 8      MTM109323
# 9      MTM109324
# 10     MTM109325
# 11     MTM109326
# 12     MTM109327
# 13     MTM109328
# 15     MTM109204
# 16     MTM109205
# 17     MTM109206
# 18     MTM109207
# 20     MTM101475
# 21     MTM101477
# 22     MTM109357
# 23     MTM109359
# 25     MTM101455
# 26     MTM101456
# 27     MTM101458
# 28     MTM101466
# Name: LEASE NO., dtype: object

# %%
shapefile["LEASE_NO"]
# Out:
# 0            NDM101156
# 1            NDM101159
# 2            NDM101160
# 3            NDM101164
# 4            NDM101166
# 5            NDM101169
# 6            NDM101172
# 7            NDM101173
# 8            NDM101180
# 9            MTM101455
# 10           MTM101456
# 11           MTM101458
# 12           MTM101464
# 13           MTM101465
# 14           MTM101475
# 15           MTM101477
# 16           NDM101479
# 17           NDM102132
# 18           NDM102136
# 19           NDM102130
# 20           SDM102222
# 21           SDM102219
# 22           SDM102226
# 23           SDM102664
# 24           SDM103746
# 25           SDM103748
# 26           SDM103750
# 27           SDM103751
# 28           SDM103758
# 29           SDM103761
#              ...
# 1439        NMNM139876
# 1440        NMNM139877
# 1441        NMNM139878
# 1442        NMNM139879
# 1443        NMNM140301
# 1444        NMNM140302
# 1445        KSNM140298
# 1446    WY2020-03-6024
# 1447    WY2020-03-6183
# 1448    WY2020-03-6229
# 1449    WY2020-03-6230
# 1450    WY2020-03-6231
# 1451    WY2020-03-6264
# 1452    WY2020-03-6317
# 1453    WY2020-03-6321
# 1454    WY2020-03-6324
# 1455    WY2020-03-6331
# 1456    WY2020-03-6333
# 1457    WY2020-03-6335
# 1458    WY2020-03-6342
# 1459    WY2020-03-6358
# 1460    WY2020-03-6398
# 1461    WY2020-03-6399
# 1462    WY2020-03-6400
# 1463    WY2020-03-6401
# 1464    WY2020-03-6402
# 1465    WY2020-03-6403
# 1466    WY2020-03-6655
# 1467    WY2020-03-6601
# 1468    WY2020-03-6607
# Name: LEASE_NO, Length: 1469, dtype: object

# %%
#creating version of master shapefile with serial numbers found in the rental list
RentalShapeFile = shapefile.loc[shapefile["LEASE_NO"].isin(SerialNumbers)]

# %%
#checking lenghts of each variable to see if matches were found
RentalShapeFile["LEASE_NO"].count()
SerialNumbers.count()
# Out:
# 40
# 40

# %% [markdown]
# # IF Mismatches - Section for Cleaning Lease Numbers Text

# %%
testSerial = SerialNumbers.loc[146]

testSerial
re.findall('[\w]+', testSerial)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: 146
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-187c2655dcc8> in <module>
# ----> 1 testSerial = SerialNumbers.loc[146]
#       2
#       3 testSerial
#       4 re.findall('[\w]+', testSerial)[0]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     135             # but will fail when the index is not present
#     136             # see GH5667
# --> 137             return self.obj._xs(label, axis=axis)
#     138         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     139             raise IndexingError('no slices here, handle elsewhere')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: 146

# %%
#creating function to run on a pandas series to clean up mistakenly placed special chars at end of serial number on rental spreadsheet
def replaceSpecialChars(serial):
    cleanedSerial = re.findall('[\w]+', serial)[0]
    return cleanedSerial

# %%
CleanedSerials = SerialNumbers.apply(lambda x: replaceSpecialChars(x))

# %%
RentalShapeFile = shapefile.loc[shapefile["LEASE_NO"].isin(CleanedSerials)]

# %%
RentalShapeFile["LEASE_NO"].count()
SerialNumbers.count()

# %% [markdown]
# # Writing RentalShapefile to File

# %%
RentalShapeFile.to_file(month + " 2020 - Rental Tracts.shp")

# %% [markdown]
# # Adding DI County Format for Filtering

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
#inversing dictionary
statetoInits = {v: k for k, v in states.items()}

# %%
#cleaning datatypes for State
RentalList.info()
RentalList["STATE"] = RentalList["STATE"].astype(str)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 28
# Data columns (total 9 columns):
# LEASE NO.           40 non-null object
# COUNTY              40 non-null object
# STATE               40 non-null object
# EXPIRATION          40 non-null datetime64[ns]
# ACRES               40 non-null float64
# RENTAL              40 non-null float64
# COUNTY.1            11 non-null float64
# Y/N                 0 non-null float64
# Mishaun Comments    40 non-null object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 3.1+ KB

# %%
#Adding Columnn with State abbreviations for each state by mapping state dictionary
RentalList["St. Initials"] = RentalList["STATE"].apply(lambda x: x.title()).map(statetoInits)

RentalList
# Out:
#      LEASE NO.        COUNTY       STATE EXPIRATION    ACRES  RENTAL  \
# 0    MTM110982        BLAINE     MONTANA 2029-07-01    40.00    60.0
# 1    MTM110983        BLAINE     MONTANA 2029-07-01    80.00   120.0
# 2    MTM110985        BLAINE     MONTANA 2029-07-01   430.50   646.5
# 4    MTM111016        DAWSON     MONTANA 2029-07-01   160.00   240.0
# 5    MTM111017        DAWSON     MONTANA 2029-07-01   480.00   720.0
# 6    MTM111022        DAWSON     MONTANA 2029-07-01  2080.00  3120.0
# 8    MTM110971   MUSSELSHELL     MONTANA 2029-07-01   338.59   508.5
# 9    MTM110972   MUSSELSHELL     MONTANA 2029-07-01   770.53  1156.5
# 10   MTM110973   MUSSELSHELL     MONTANA 2029-07-01   240.00   360.0
# 11   MTM110974   MUSSELSHELL     MONTANA 2029-07-01  1124.09  1687.5
# 12   MTM110975   MUSSELSHELL     MONTANA 2029-07-01   327.08   492.0
# 14   MTM110986         TOOLE     MONTANA 2029-07-01   240.92   361.5
# 16  NMNM128371    RIO ARRIBA  NEW MEXICO 2022-07-01   480.00   960.0
# 17  NMNM128376    RIO ARRIBA  NEW MEXICO 2022-07-01   160.00   320.0
# 19  OKNM128387        GARVIN    OKLAHOMA 2022-07-01    20.00    40.0
# 0    MTM101460        DAWSON     MONTANA 2021-07-01  1193.80  2388.0
# 1    MTM101461        DAWSON     MONTANA 2021-07-01   920.00  1840.0
# 2    MTM101462        DAWSON     MONTANA 2021-07-01   864.95  1730.0
# 3    MTM101463        DAWSON     MONTANA 2021-07-01   803.90  1608.0
# 4    MTM101464        DAWSON     MONTANA 2021-07-01   320.00   640.0
# 5    MTM101465        DAWSON     MONTANA 2021-07-01   318.07   638.0
# 6    MTM101471        DAWSON     MONTANA 2021-07-01  1600.00  3200.0
# 8    MTM109323        FALLON     MONTANA 2027-07-01   160.00   240.0
# 9    MTM109324        FALLON     MONTANA 2027-07-01   120.00   180.0
# 10   MTM109325        FALLON     MONTANA 2027-07-01   160.00   240.0
# 11   MTM109326        FALLON     MONTANA 2027-07-01   280.00   420.0
# 12   MTM109327        FALLON     MONTANA 2027-07-01    40.00    60.0
# 13   MTM109328        FALLON     MONTANA 2027-07-01   200.00   300.0
# 15   MTM109204      GARFIELD     MONTANA 2027-07-01   360.00   540.0
# 16   MTM109205      GARFIELD     MONTANA 2027-07-01   240.00   360.0
# 17   MTM109206      GARFIELD     MONTANA 2027-07-01   600.00   900.0
# 18   MTM109207      GARFIELD     MONTANA 2027-07-01   120.00   180.0
# 20   MTM101475  POWDER RIVER     MONTANA 2021-07-01   960.00  1920.0
# 21   MTM101477  POWDER RIVER     MONTANA 2021-07-01  1049.60  2100.0
# 22   MTM109357  POWDER RIVER     MONTANA 2021-07-01   280.33   421.5
# 23   MTM109359  POWDER RIVER     MONTANA 2021-07-01   600.00   900.0
# 25   MTM101455      RICHLAND     MONTANA 2021-07-01    10.32    22.0
# 26   MTM101456      RICHLAND     MONTANA 2021-07-01     5.88    12.0
# 27   MTM101458      RICHLAND     MONTANA 2021-07-01    40.00    80.0
# 28   MTM101466      RICHLAND     MONTANA 2021-07-01   245.38   492.0
#
#     COUNTY.1  Y/N                                   Mishaun Comments  \
# 0        NaN  NaN                            Keep: 9 years remaining
# 1        NaN  NaN                            Keep: 9 years remaining
# 2      826.5  NaN                            Keep: 9 years remaining
# 4        NaN  NaN                            Keep: 9 years remaining
# 5        NaN  NaN                            Keep: 9 years remaining
# 6     4080.0  NaN                            Keep: 9 years remaining
# 8        NaN  NaN                            Keep: 9 years remaining
# 9        NaN  NaN                            Keep: 9 years remaining
# 10       NaN  NaN                            Keep: 9 years remaining
# 11       NaN  NaN                            Keep: 9 years remaining
# 12    4204.5  NaN                            Keep: 9 years remaining
# 14     361.5  NaN                            Keep: 9 years remaining
# 16       NaN  NaN  Maybe Let Go: No new produciton activity wihti...
# 17    1280.0  NaN  Maybe Let Go: No new produciton activity wihti...
# 19      40.0  NaN  Keep: negligible rental cost - 12 milrs away f...
# 0        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 1        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 2        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 3        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 4        NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 5        NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 6    12044.0  NaN       Maybe Let Go - east of primary fuels acreage
# 8        NaN  NaN                            Keep: 7 years remaining
# 9        NaN  NaN                            Keep: 7 years remaining
# 10       NaN  NaN                            Keep: 7 years remaining
# 11       NaN  NaN                            Keep: 7 years remaining
# 12       NaN  NaN                            Keep: 7 years remaining
# 13    1440.0  NaN                            Keep: 7 years remaining
# 15       NaN  NaN                            Keep: 7 years remaining
# 16       NaN  NaN                            Keep: 7 years remaining
# 17       NaN  NaN                            Keep: 7 years remaining
# 18    1980.0  NaN                            Keep: 7 years remaining
# 20       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 21       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 22       NaN  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 23    5341.5  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 25       NaN  NaN  Keep: negligible rental - wells around tract h...
# 26       NaN  NaN  Keep: negligible rental - closeset well near t...
# 27       NaN  NaN   Keep: neglgible rental - no activiity near tract
# 28     606.0  NaN  Maybe Let Go: Latest well to be drilled is 201...
#
#    St. Initials
# 0            MT
# 1            MT
# 2            MT
# 4            MT
# 5            MT
# 6            MT
# 8            MT
# 9            MT
# 10           MT
# 11           MT
# 12           MT
# 14           MT
# 16           NM
# 17           NM
# 19           OK
# 0            MT
# 1            MT
# 2            MT
# 3            MT
# 4            MT
# 5            MT
# 6            MT
# 8            MT
# 9            MT
# 10           MT
# 11           MT
# 12           MT
# 13           MT
# 15           MT
# 16           MT
# 17           MT
# 18           MT
# 20           MT
# 21           MT
# 22           MT
# 23           MT
# 25           MT
# 26           MT
# 27           MT
# 28           MT

# %%
#Creating Column with DI Counties Format Name
RentalList["DI Counties"] = RentalList["COUNTY"] + " (" + RentalList["St. Initials"] + ")"

# %%
RentalList
# Out:
#      LEASE NO.        COUNTY       STATE EXPIRATION    ACRES  RENTAL  \
# 0    MTM110982        BLAINE     MONTANA 2029-07-01    40.00    60.0
# 1    MTM110983        BLAINE     MONTANA 2029-07-01    80.00   120.0
# 2    MTM110985        BLAINE     MONTANA 2029-07-01   430.50   646.5
# 4    MTM111016        DAWSON     MONTANA 2029-07-01   160.00   240.0
# 5    MTM111017        DAWSON     MONTANA 2029-07-01   480.00   720.0
# 6    MTM111022        DAWSON     MONTANA 2029-07-01  2080.00  3120.0
# 8    MTM110971   MUSSELSHELL     MONTANA 2029-07-01   338.59   508.5
# 9    MTM110972   MUSSELSHELL     MONTANA 2029-07-01   770.53  1156.5
# 10   MTM110973   MUSSELSHELL     MONTANA 2029-07-01   240.00   360.0
# 11   MTM110974   MUSSELSHELL     MONTANA 2029-07-01  1124.09  1687.5
# 12   MTM110975   MUSSELSHELL     MONTANA 2029-07-01   327.08   492.0
# 14   MTM110986         TOOLE     MONTANA 2029-07-01   240.92   361.5
# 16  NMNM128371    RIO ARRIBA  NEW MEXICO 2022-07-01   480.00   960.0
# 17  NMNM128376    RIO ARRIBA  NEW MEXICO 2022-07-01   160.00   320.0
# 19  OKNM128387        GARVIN    OKLAHOMA 2022-07-01    20.00    40.0
# 0    MTM101460        DAWSON     MONTANA 2021-07-01  1193.80  2388.0
# 1    MTM101461        DAWSON     MONTANA 2021-07-01   920.00  1840.0
# 2    MTM101462        DAWSON     MONTANA 2021-07-01   864.95  1730.0
# 3    MTM101463        DAWSON     MONTANA 2021-07-01   803.90  1608.0
# 4    MTM101464        DAWSON     MONTANA 2021-07-01   320.00   640.0
# 5    MTM101465        DAWSON     MONTANA 2021-07-01   318.07   638.0
# 6    MTM101471        DAWSON     MONTANA 2021-07-01  1600.00  3200.0
# 8    MTM109323        FALLON     MONTANA 2027-07-01   160.00   240.0
# 9    MTM109324        FALLON     MONTANA 2027-07-01   120.00   180.0
# 10   MTM109325        FALLON     MONTANA 2027-07-01   160.00   240.0
# 11   MTM109326        FALLON     MONTANA 2027-07-01   280.00   420.0
# 12   MTM109327        FALLON     MONTANA 2027-07-01    40.00    60.0
# 13   MTM109328        FALLON     MONTANA 2027-07-01   200.00   300.0
# 15   MTM109204      GARFIELD     MONTANA 2027-07-01   360.00   540.0
# 16   MTM109205      GARFIELD     MONTANA 2027-07-01   240.00   360.0
# 17   MTM109206      GARFIELD     MONTANA 2027-07-01   600.00   900.0
# 18   MTM109207      GARFIELD     MONTANA 2027-07-01   120.00   180.0
# 20   MTM101475  POWDER RIVER     MONTANA 2021-07-01   960.00  1920.0
# 21   MTM101477  POWDER RIVER     MONTANA 2021-07-01  1049.60  2100.0
# 22   MTM109357  POWDER RIVER     MONTANA 2021-07-01   280.33   421.5
# 23   MTM109359  POWDER RIVER     MONTANA 2021-07-01   600.00   900.0
# 25   MTM101455      RICHLAND     MONTANA 2021-07-01    10.32    22.0
# 26   MTM101456      RICHLAND     MONTANA 2021-07-01     5.88    12.0
# 27   MTM101458      RICHLAND     MONTANA 2021-07-01    40.00    80.0
# 28   MTM101466      RICHLAND     MONTANA 2021-07-01   245.38   492.0
#
#     COUNTY.1  Y/N                                   Mishaun Comments  \
# 0        NaN  NaN                            Keep: 9 years remaining
# 1        NaN  NaN                            Keep: 9 years remaining
# 2      826.5  NaN                            Keep: 9 years remaining
# 4        NaN  NaN                            Keep: 9 years remaining
# 5        NaN  NaN                            Keep: 9 years remaining
# 6     4080.0  NaN                            Keep: 9 years remaining
# 8        NaN  NaN                            Keep: 9 years remaining
# 9        NaN  NaN                            Keep: 9 years remaining
# 10       NaN  NaN                            Keep: 9 years remaining
# 11       NaN  NaN                            Keep: 9 years remaining
# 12    4204.5  NaN                            Keep: 9 years remaining
# 14     361.5  NaN                            Keep: 9 years remaining
# 16       NaN  NaN  Maybe Let Go: No new produciton activity wihti...
# 17    1280.0  NaN  Maybe Let Go: No new produciton activity wihti...
# 19      40.0  NaN  Keep: negligible rental cost - 12 milrs away f...
# 0        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 1        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 2        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 3        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 4        NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 5        NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 6    12044.0  NaN       Maybe Let Go - east of primary fuels acreage
# 8        NaN  NaN                            Keep: 7 years remaining
# 9        NaN  NaN                            Keep: 7 years remaining
# 10       NaN  NaN                            Keep: 7 years remaining
# 11       NaN  NaN                            Keep: 7 years remaining
# 12       NaN  NaN                            Keep: 7 years remaining
# 13    1440.0  NaN                            Keep: 7 years remaining
# 15       NaN  NaN                            Keep: 7 years remaining
# 16       NaN  NaN                            Keep: 7 years remaining
# 17       NaN  NaN                            Keep: 7 years remaining
# 18    1980.0  NaN                            Keep: 7 years remaining
# 20       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 21       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 22       NaN  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 23    5341.5  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 25       NaN  NaN  Keep: negligible rental - wells around tract h...
# 26       NaN  NaN  Keep: negligible rental - closeset well near t...
# 27       NaN  NaN   Keep: neglgible rental - no activiity near tract
# 28     606.0  NaN  Maybe Let Go: Latest well to be drilled is 201...
#
#    St. Initials        DI Counties
# 0            MT        BLAINE (MT)
# 1            MT        BLAINE (MT)
# 2            MT        BLAINE (MT)
# 4            MT        DAWSON (MT)
# 5            MT        DAWSON (MT)
# 6            MT        DAWSON (MT)
# 8            MT   MUSSELSHELL (MT)
# 9            MT   MUSSELSHELL (MT)
# 10           MT   MUSSELSHELL (MT)
# 11           MT   MUSSELSHELL (MT)
# 12           MT   MUSSELSHELL (MT)
# 14           MT         TOOLE (MT)
# 16           NM    RIO ARRIBA (NM)
# 17           NM    RIO ARRIBA (NM)
# 19           OK        GARVIN (OK)
# 0            MT        DAWSON (MT)
# 1            MT        DAWSON (MT)
# 2            MT        DAWSON (MT)
# 3            MT        DAWSON (MT)
# 4            MT        DAWSON (MT)
# 5            MT        DAWSON (MT)
# 6            MT        DAWSON (MT)
# 8            MT        FALLON (MT)
# 9            MT        FALLON (MT)
# 10           MT        FALLON (MT)
# 11           MT        FALLON (MT)
# 12           MT        FALLON (MT)
# 13           MT        FALLON (MT)
# 15           MT      GARFIELD (MT)
# 16           MT      GARFIELD (MT)
# 17           MT      GARFIELD (MT)
# 18           MT      GARFIELD (MT)
# 20           MT  POWDER RIVER (MT)
# 21           MT  POWDER RIVER (MT)
# 22           MT  POWDER RIVER (MT)
# 23           MT  POWDER RIVER (MT)
# 25           MT      RICHLAND (MT)
# 26           MT      RICHLAND (MT)
# 27           MT      RICHLAND (MT)
# 28           MT      RICHLAND (MT)

# %%
#output for DI counties - copy and paste into DI
for i in RentalList["DI Counties"].drop_duplicates():
    print(i)
# Out:
# BLAINE (MT)
# DAWSON (MT)
# MUSSELSHELL (MT)
# TOOLE (MT)
# RIO ARRIBA (NM)
# GARVIN (OK)
# FALLON (MT)
# GARFIELD (MT)
# POWDER RIVER (MT)
# RICHLAND (MT)
