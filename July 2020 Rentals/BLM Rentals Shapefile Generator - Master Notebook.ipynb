# %%
import pandas as pd
import geopandas as gpd
import re

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
month = "July"

# %% [markdown]
# # Reading In Rental List - Magnum and R&R

# %%
#R&R and Magnum Rental List
RRList = pd.read_excel("BLM Rents July 2020.xlsx", header = 4, usecols = 8)
MPLPList = pd.read_excel("BLM Rents July 2020.xlsx", header = 4, usecols = 8, sheet_name = "MPLP")
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/io/excel.py:527: FutureWarning: Passing in an integer for `usecols` has been deprecated. Please pass in a list of int from 0 to `usecols` inclusive instead.
#   usecols = _maybe_convert_usecols(usecols)

# %%
#Reading Mastr shapefile
shapefile = gpd.read_file("zip://Master Shapefile 4-2-20.zip")
shapefile.columns
# Out:
# Index(['OBJECTID_1', 'OBJECTID_2', 'OBJECTID', 'LEASE_NO', 'EFFECTIVE',
#        'EXPIRATION', 'TOTAL_PAID', 'ACRES', 'COUNTY', 'ST', 'Ownership',
#        'Shape_Leng', 'GeneralLoc', 'Due_Year', 'DUE_DATE', 'NO__OF_ACR',
#        'HYPERLINK', 'Comments', 'Shape_Le_1', 'Shape_Le_2', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
RRList
MPLPList
# Out:
#      LEASE NO.       COUNTY       STATE EXPIRATION    ACRES   RENTAL  \
# 0    MTM110982       BLAINE     MONTANA 2029-07-01    40.00     60.0
# 1    MTM110983       BLAINE     MONTANA 2029-07-01    80.00    120.0
# 2    MTM110985       BLAINE     MONTANA 2029-07-01   430.50    646.5
# 3          NaN          NaN         NaN        NaT      NaN      NaN
# 4    MTM111016       DAWSON     MONTANA 2029-07-01   160.00    240.0
# 5    MTM111017       DAWSON     MONTANA 2029-07-01   480.00    720.0
# 6    MTM111022       DAWSON     MONTANA 2029-07-01  2080.00   3120.0
# 7          NaN          NaN         NaN        NaT      NaN      NaN
# 8    MTM110971  MUSSELSHELL     MONTANA 2029-07-01   338.59    508.5
# 9    MTM110972  MUSSELSHELL     MONTANA 2029-07-01   770.53   1156.5
# 10   MTM110973  MUSSELSHELL     MONTANA 2029-07-01   240.00    360.0
# 11   MTM110974  MUSSELSHELL     MONTANA 2029-07-01  1124.09   1687.5
# 12   MTM110975  MUSSELSHELL     MONTANA 2029-07-01   327.08    492.0
# 13         NaN          NaN         NaN        NaT      NaN      NaN
# 14   MTM110986        TOOLE     MONTANA 2029-07-01   240.92    361.5
# 15         NaN          NaN         NaN        NaT      NaN      NaN
# 16  NMNM128371   RIO ARRIBA  NEW MEXICO 2022-07-01   480.00    960.0
# 17  NMNM128376   RIO ARRIBA  NEW MEXICO 2022-07-01   160.00    320.0
# 18         NaN          NaN         NaN        NaT      NaN      NaN
# 19  OKNM128387       GARVIN    OKLAHOMA 2022-07-01    20.00     40.0
# 20         NaN          NaN         NaN        NaT      NaN  10792.5
#
#     COUNTY.1  Y/N                                   Mishaun Comments
# 0        NaN  NaN                            Keep: 9 years remaining
# 1        NaN  NaN                            Keep: 9 years remaining
# 2      826.5  NaN                            Keep: 9 years remaining
# 3        NaN  NaN                                                NaN
# 4        NaN  NaN                            Keep: 9 years remaining
# 5        NaN  NaN                            Keep: 9 years remaining
# 6     4080.0  NaN                            Keep: 9 years remaining
# 7        NaN  NaN                                                NaN
# 8        NaN  NaN                            Keep: 9 years remaining
# 9        NaN  NaN                            Keep: 9 years remaining
# 10       NaN  NaN                            Keep: 9 years remaining
# 11       NaN  NaN                            Keep: 9 years remaining
# 12    4204.5  NaN                            Keep: 9 years remaining
# 13       NaN  NaN                                                NaN
# 14     361.5  NaN                            Keep: 9 years remaining
# 15       NaN  NaN                                                NaN
# 16       NaN  NaN  Maybe Let Go: No new produciton activity wihti...
# 17    1280.0  NaN  Maybe Let Go: No new produciton activity wihti...
# 18       NaN  NaN                                                NaN
# 19      40.0  NaN  Keep: negligible rental cost - 12 milrs away f...
# 20   10752.5  NaN                                                NaN
#     LEASE NO.        COUNTY    STATE EXPIRATION    ACRES   RENTAL  COUNTY.1  \
# 0   MTM101460        DAWSON  MONTANA 2021-07-01  1193.80   2388.0       NaN
# 1   MTM101461        DAWSON  MONTANA 2021-07-01   920.00   1840.0       NaN
# 2   MTM101462        DAWSON  MONTANA 2021-07-01   864.95   1730.0       NaN
# 3   MTM101463        DAWSON  MONTANA 2021-07-01   803.90   1608.0       NaN
# 4   MTM101464        DAWSON  MONTANA 2021-07-01   320.00    640.0       NaN
# 5   MTM101465        DAWSON  MONTANA 2021-07-01   318.07    638.0       NaN
# 6   MTM101471        DAWSON  MONTANA 2021-07-01  1600.00   3200.0   12044.0
# 7         NaN           NaN      NaN        NaT      NaN      NaN       NaN
# 8   MTM109323        FALLON  MONTANA 2027-07-01   160.00    240.0       NaN
# 9   MTM109324        FALLON  MONTANA 2027-07-01   120.00    180.0       NaN
# 10  MTM109325        FALLON  MONTANA 2027-07-01   160.00    240.0       NaN
# 11  MTM109326        FALLON  MONTANA 2027-07-01   280.00    420.0       NaN
# 12  MTM109327        FALLON  MONTANA 2027-07-01    40.00     60.0       NaN
# 13  MTM109328        FALLON  MONTANA 2027-07-01   200.00    300.0    1440.0
# 14        NaN           NaN      NaN        NaT      NaN      NaN       NaN
# 15  MTM109204      GARFIELD  MONTANA 2027-07-01   360.00    540.0       NaN
# 16  MTM109205      GARFIELD  MONTANA 2027-07-01   240.00    360.0       NaN
# 17  MTM109206      GARFIELD  MONTANA 2027-07-01   600.00    900.0       NaN
# 18  MTM109207      GARFIELD  MONTANA 2027-07-01   120.00    180.0    1980.0
# 19        NaN           NaN      NaN        NaT      NaN      NaN       NaN
# 20  MTM101475  POWDER RIVER  MONTANA 2021-07-01   960.00   1920.0       NaN
# 21  MTM101477  POWDER RIVER  MONTANA 2021-07-01  1049.60   2100.0       NaN
# 22  MTM109357  POWDER RIVER  MONTANA 2021-07-01   280.33    421.5       NaN
# 23  MTM109359  POWDER RIVER  MONTANA 2021-07-01   600.00    900.0    5341.5
# 24        NaN           NaN      NaN        NaT      NaN      NaN       NaN
# 25  MTM101455      RICHLAND  MONTANA 2021-07-01    10.32     22.0       NaN
# 26  MTM101456      RICHLAND  MONTANA 2021-07-01     5.88     12.0       NaN
# 27  MTM101458      RICHLAND  MONTANA 2021-07-01    40.00     80.0       NaN
# 28  MTM101466      RICHLAND  MONTANA 2021-07-01   245.38    492.0     606.0
# 29        NaN           NaN      NaN        NaT      NaN  21411.5   21411.5
#
#     Y/N                                   Mishaun Comments
# 0   NaN       Keep: In the middle of Primary Fuels Acreage
# 1   NaN       Keep: In the middle of Primary Fuels Acreage
# 2   NaN       Keep: In the middle of Primary Fuels Acreage
# 3   NaN       Keep: In the middle of Primary Fuels Acreage
# 4   NaN  Consider Letting Go: Northern Part of Dawson -...
# 5   NaN  Consider Letting Go: Northern Part of Dawson -...
# 6   NaN       Maybe Let Go - east of primary fuels acreage
# 7   NaN                                                NaN
# 8   NaN                            Keep: 7 years remaining
# 9   NaN                            Keep: 7 years remaining
# 10  NaN                            Keep: 7 years remaining
# 11  NaN                            Keep: 7 years remaining
# 12  NaN                            Keep: 7 years remaining
# 13  NaN                            Keep: 7 years remaining
# 14  NaN                                                NaN
# 15  NaN                            Keep: 7 years remaining
# 16  NaN                            Keep: 7 years remaining
# 17  NaN                            Keep: 7 years remaining
# 18  NaN                            Keep: 7 years remaining
# 19  NaN                                                NaN
# 20  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 21  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 22  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 23  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 24  NaN                                                NaN
# 25  NaN  Keep: negligible rental - wells around tract h...
# 26  NaN  Keep: negligible rental - closeset well near t...
# 27  NaN   Keep: neglgible rental - no activiity near tract
# 28  NaN  Maybe Let Go: Latest well to be drilled is 201...
# 29  NaN                                                NaN

# %% [markdown]
# ## Concatenating Magnum and RR Into 1 Dataframe
# ### Cleaning Dataframe by removing null rows, subtotal rows, etc

# %%
#concat magnum and r&r rental list
RentalList = pd.concat([RRList, MPLPList])

# %%
#dropping rows with null values for lease number and county
RentalList.dropna(subset = ["LEASE NO.", "COUNTY"], how = 'all', inplace = True)

#resetting index
RentalList.reset_index(inplace = True)

RentalList
# Out:
#     index   LEASE NO.        COUNTY       STATE EXPIRATION    ACRES  RENTAL  \
# 0       0   MTM110982        BLAINE     MONTANA 2029-07-01    40.00    60.0
# 1       1   MTM110983        BLAINE     MONTANA 2029-07-01    80.00   120.0
# 2       2   MTM110985        BLAINE     MONTANA 2029-07-01   430.50   646.5
# 3       4   MTM111016        DAWSON     MONTANA 2029-07-01   160.00   240.0
# 4       5   MTM111017        DAWSON     MONTANA 2029-07-01   480.00   720.0
# 5       6   MTM111022        DAWSON     MONTANA 2029-07-01  2080.00  3120.0
# 6       8   MTM110971   MUSSELSHELL     MONTANA 2029-07-01   338.59   508.5
# 7       9   MTM110972   MUSSELSHELL     MONTANA 2029-07-01   770.53  1156.5
# 8      10   MTM110973   MUSSELSHELL     MONTANA 2029-07-01   240.00   360.0
# 9      11   MTM110974   MUSSELSHELL     MONTANA 2029-07-01  1124.09  1687.5
# 10     12   MTM110975   MUSSELSHELL     MONTANA 2029-07-01   327.08   492.0
# 11     14   MTM110986         TOOLE     MONTANA 2029-07-01   240.92   361.5
# 12     16  NMNM128371    RIO ARRIBA  NEW MEXICO 2022-07-01   480.00   960.0
# 13     17  NMNM128376    RIO ARRIBA  NEW MEXICO 2022-07-01   160.00   320.0
# 14     19  OKNM128387        GARVIN    OKLAHOMA 2022-07-01    20.00    40.0
# 15      0   MTM101460        DAWSON     MONTANA 2021-07-01  1193.80  2388.0
# 16      1   MTM101461        DAWSON     MONTANA 2021-07-01   920.00  1840.0
# 17      2   MTM101462        DAWSON     MONTANA 2021-07-01   864.95  1730.0
# 18      3   MTM101463        DAWSON     MONTANA 2021-07-01   803.90  1608.0
# 19      4   MTM101464        DAWSON     MONTANA 2021-07-01   320.00   640.0
# 20      5   MTM101465        DAWSON     MONTANA 2021-07-01   318.07   638.0
# 21      6   MTM101471        DAWSON     MONTANA 2021-07-01  1600.00  3200.0
# 22      8   MTM109323        FALLON     MONTANA 2027-07-01   160.00   240.0
# 23      9   MTM109324        FALLON     MONTANA 2027-07-01   120.00   180.0
# 24     10   MTM109325        FALLON     MONTANA 2027-07-01   160.00   240.0
# 25     11   MTM109326        FALLON     MONTANA 2027-07-01   280.00   420.0
# 26     12   MTM109327        FALLON     MONTANA 2027-07-01    40.00    60.0
# 27     13   MTM109328        FALLON     MONTANA 2027-07-01   200.00   300.0
# 28     15   MTM109204      GARFIELD     MONTANA 2027-07-01   360.00   540.0
# 29     16   MTM109205      GARFIELD     MONTANA 2027-07-01   240.00   360.0
# 30     17   MTM109206      GARFIELD     MONTANA 2027-07-01   600.00   900.0
# 31     18   MTM109207      GARFIELD     MONTANA 2027-07-01   120.00   180.0
# 32     20   MTM101475  POWDER RIVER     MONTANA 2021-07-01   960.00  1920.0
# 33     21   MTM101477  POWDER RIVER     MONTANA 2021-07-01  1049.60  2100.0
# 34     22   MTM109357  POWDER RIVER     MONTANA 2021-07-01   280.33   421.5
# 35     23   MTM109359  POWDER RIVER     MONTANA 2021-07-01   600.00   900.0
# 36     25   MTM101455      RICHLAND     MONTANA 2021-07-01    10.32    22.0
# 37     26   MTM101456      RICHLAND     MONTANA 2021-07-01     5.88    12.0
# 38     27   MTM101458      RICHLAND     MONTANA 2021-07-01    40.00    80.0
# 39     28   MTM101466      RICHLAND     MONTANA 2021-07-01   245.38   492.0
#
#     COUNTY.1  Y/N                                   Mishaun Comments  \
# 0        NaN  NaN                            Keep: 9 years remaining
# 1        NaN  NaN                            Keep: 9 years remaining
# 2      826.5  NaN                            Keep: 9 years remaining
# 3        NaN  NaN                            Keep: 9 years remaining
# 4        NaN  NaN                            Keep: 9 years remaining
# 5     4080.0  NaN                            Keep: 9 years remaining
# 6        NaN  NaN                            Keep: 9 years remaining
# 7        NaN  NaN                            Keep: 9 years remaining
# 8        NaN  NaN                            Keep: 9 years remaining
# 9        NaN  NaN                            Keep: 9 years remaining
# 10    4204.5  NaN                            Keep: 9 years remaining
# 11     361.5  NaN                            Keep: 9 years remaining
# 12       NaN  NaN  Maybe Let Go: No new produciton activity wihti...
# 13    1280.0  NaN  Maybe Let Go: No new produciton activity wihti...
# 14      40.0  NaN  Keep: negligible rental cost - 12 milrs away f...
# 15       NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 16       NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 17       NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 18       NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 19       NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 20       NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 21   12044.0  NaN       Maybe Let Go - east of primary fuels acreage
# 22       NaN  NaN                            Keep: 7 years remaining
# 23       NaN  NaN                            Keep: 7 years remaining
# 24       NaN  NaN                            Keep: 7 years remaining
# 25       NaN  NaN                            Keep: 7 years remaining
# 26       NaN  NaN                            Keep: 7 years remaining
# 27    1440.0  NaN                            Keep: 7 years remaining
# 28       NaN  NaN                            Keep: 7 years remaining
# 29       NaN  NaN                            Keep: 7 years remaining
# 30       NaN  NaN                            Keep: 7 years remaining
# 31    1980.0  NaN                            Keep: 7 years remaining
# 32       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 33       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 34       NaN  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 35    5341.5  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 36       NaN  NaN  Keep: negligible rental - wells around tract h...
# 37       NaN  NaN  Keep: negligible rental - closeset well near t...
# 38       NaN  NaN   Keep: neglgible rental - no activiity near tract
# 39     606.0  NaN  Maybe Let Go: Latest well to be drilled is 201...
#
#    St. Initials        DI Counties
# 0            MT        BLAINE (MT)
# 1            MT        BLAINE (MT)
# 2            MT        BLAINE (MT)
# 3            MT        DAWSON (MT)
# 4            MT        DAWSON (MT)
# 5            MT        DAWSON (MT)
# 6            MT   MUSSELSHELL (MT)
# 7            MT   MUSSELSHELL (MT)
# 8            MT   MUSSELSHELL (MT)
# 9            MT   MUSSELSHELL (MT)
# 10           MT   MUSSELSHELL (MT)
# 11           MT         TOOLE (MT)
# 12           NM    RIO ARRIBA (NM)
# 13           NM    RIO ARRIBA (NM)
# 14           OK        GARVIN (OK)
# 15           MT        DAWSON (MT)
# 16           MT        DAWSON (MT)
# 17           MT        DAWSON (MT)
# 18           MT        DAWSON (MT)
# 19           MT        DAWSON (MT)
# 20           MT        DAWSON (MT)
# 21           MT        DAWSON (MT)
# 22           MT        FALLON (MT)
# 23           MT        FALLON (MT)
# 24           MT        FALLON (MT)
# 25           MT        FALLON (MT)
# 26           MT        FALLON (MT)
# 27           MT        FALLON (MT)
# 28           MT      GARFIELD (MT)
# 29           MT      GARFIELD (MT)
# 30           MT      GARFIELD (MT)
# 31           MT      GARFIELD (MT)
# 32           MT  POWDER RIVER (MT)
# 33           MT  POWDER RIVER (MT)
# 34           MT  POWDER RIVER (MT)
# 35           MT  POWDER RIVER (MT)
# 36           MT      RICHLAND (MT)
# 37           MT      RICHLAND (MT)
# 38           MT      RICHLAND (MT)
# 39           MT      RICHLAND (MT)

# %%
#storing serial numbers found in RentalLis
SerialNumbers = RentalList.loc[:,"LEASE NO."]

SerialNumbers.dropna(inplace = True)

SerialNumbers
# Out:
# 0      MTM110982
# 1      MTM110983
# 2      MTM110985
# 4      MTM111016
# 5      MTM111017
# 6      MTM111022
# 8      MTM110971
# 9      MTM110972
# 10     MTM110973
# 11     MTM110974
# 12     MTM110975
# 14     MTM110986
# 16    NMNM128371
# 17    NMNM128376
# 19    OKNM128387
# 0      MTM101460
# 1      MTM101461
# 2      MTM101462
# 3      MTM101463
# 4      MTM101464
# 5      MTM101465
# 6      MTM101471
# 8      MTM109323
# 9      MTM109324
# 10     MTM109325
# 11     MTM109326
# 12     MTM109327
# 13     MTM109328
# 15     MTM109204
# 16     MTM109205
# 17     MTM109206
# 18     MTM109207
# 20     MTM101475
# 21     MTM101477
# 22     MTM109357
# 23     MTM109359
# 25     MTM101455
# 26     MTM101456
# 27     MTM101458
# 28     MTM101466
# Name: LEASE NO., dtype: object

# %%
shapefile["LEASE_NO"]
# Out:
# 0            NDM101156
# 1            NDM101159
# 2            NDM101160
# 3            NDM101164
# 4            NDM101166
# 5            NDM101169
# 6            NDM101172
# 7            NDM101173
# 8            NDM101180
# 9            MTM101455
# 10           MTM101456
# 11           MTM101458
# 12           MTM101464
# 13           MTM101465
# 14           MTM101475
# 15           MTM101477
# 16           NDM101479
# 17           NDM102132
# 18           NDM102136
# 19           NDM102130
# 20           SDM102222
# 21           SDM102219
# 22           SDM102226
# 23           SDM102664
# 24           SDM103746
# 25           SDM103748
# 26           SDM103750
# 27           SDM103751
# 28           SDM103758
# 29           SDM103761
#              ...
# 1439        NMNM139876
# 1440        NMNM139877
# 1441        NMNM139878
# 1442        NMNM139879
# 1443        NMNM140301
# 1444        NMNM140302
# 1445        KSNM140298
# 1446    WY2020-03-6024
# 1447    WY2020-03-6183
# 1448    WY2020-03-6229
# 1449    WY2020-03-6230
# 1450    WY2020-03-6231
# 1451    WY2020-03-6264
# 1452    WY2020-03-6317
# 1453    WY2020-03-6321
# 1454    WY2020-03-6324
# 1455    WY2020-03-6331
# 1456    WY2020-03-6333
# 1457    WY2020-03-6335
# 1458    WY2020-03-6342
# 1459    WY2020-03-6358
# 1460    WY2020-03-6398
# 1461    WY2020-03-6399
# 1462    WY2020-03-6400
# 1463    WY2020-03-6401
# 1464    WY2020-03-6402
# 1465    WY2020-03-6403
# 1466    WY2020-03-6655
# 1467    WY2020-03-6601
# 1468    WY2020-03-6607
# Name: LEASE_NO, Length: 1469, dtype: object

# %%
#creating version of master shapefile with serial numbers found in the rental list
RentalShapeFile = shapefile.loc[shapefile["LEASE_NO"].isin(SerialNumbers)]

# %%
#checking lenghts of each variable to see if matches were found
RentalShapeFile["LEASE_NO"].count()
SerialNumbers.count()
# Out:
# 40
# 40

# %% [markdown]
# # IF Mismatches - Section for Cleaning Lease Numbers Text

# %%
testSerial = SerialNumbers.loc[146]

testSerial
re.findall('[\w]+', testSerial)[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: 146
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-187c2655dcc8> in <module>
# ----> 1 testSerial = SerialNumbers.loc[146]
#       2
#       3 testSerial
#       4 re.findall('[\w]+', testSerial)[0]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     135             # but will fail when the index is not present
#     136             # see GH5667
# --> 137             return self.obj._xs(label, axis=axis)
#     138         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     139             raise IndexingError('no slices here, handle elsewhere')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# KeyError: 146

# %%
#creating function to run on a pandas series to clean up mistakenly placed special chars at end of serial number on rental spreadsheet
def replaceSpecialChars(serial):
    cleanedSerial = re.findall('[\w]+', serial)[0]
    return cleanedSerial

# %%
CleanedSerials = SerialNumbers.apply(lambda x: replaceSpecialChars(x))

# %%
RentalShapeFile = shapefile.loc[shapefile["LEASE_NO"].isin(CleanedSerials)]

# %%
RentalShapeFile["LEASE_NO"].count()
SerialNumbers.count()

# %% [markdown]
# # Writing RentalShapefile to File

# %%
RentalShapeFile.to_file(month + " 2020 - Rental Tracts.shp")

# %% [markdown]
# # Adding DI County Format for Filtering

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
#inversing dictionary
statetoInits = {v: k for k, v in states.items()}

# %%
#cleaning datatypes for State
RentalList.info()
RentalList["STATE"] = RentalList["STATE"].astype(str)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 0 to 28
# Data columns (total 9 columns):
# LEASE NO.           40 non-null object
# COUNTY              40 non-null object
# STATE               40 non-null object
# EXPIRATION          40 non-null datetime64[ns]
# ACRES               40 non-null float64
# RENTAL              40 non-null float64
# COUNTY.1            11 non-null float64
# Y/N                 0 non-null float64
# Mishaun Comments    40 non-null object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 3.1+ KB

# %%
#Adding Columnn with State abbreviations for each state by mapping state dictionary
RentalList["St. Initials"] = RentalList["STATE"].apply(lambda x: x.title()).map(statetoInits)

RentalList
# Out:
#      LEASE NO.        COUNTY       STATE EXPIRATION    ACRES  RENTAL  \
# 0    MTM110982        BLAINE     MONTANA 2029-07-01    40.00    60.0
# 1    MTM110983        BLAINE     MONTANA 2029-07-01    80.00   120.0
# 2    MTM110985        BLAINE     MONTANA 2029-07-01   430.50   646.5
# 4    MTM111016        DAWSON     MONTANA 2029-07-01   160.00   240.0
# 5    MTM111017        DAWSON     MONTANA 2029-07-01   480.00   720.0
# 6    MTM111022        DAWSON     MONTANA 2029-07-01  2080.00  3120.0
# 8    MTM110971   MUSSELSHELL     MONTANA 2029-07-01   338.59   508.5
# 9    MTM110972   MUSSELSHELL     MONTANA 2029-07-01   770.53  1156.5
# 10   MTM110973   MUSSELSHELL     MONTANA 2029-07-01   240.00   360.0
# 11   MTM110974   MUSSELSHELL     MONTANA 2029-07-01  1124.09  1687.5
# 12   MTM110975   MUSSELSHELL     MONTANA 2029-07-01   327.08   492.0
# 14   MTM110986         TOOLE     MONTANA 2029-07-01   240.92   361.5
# 16  NMNM128371    RIO ARRIBA  NEW MEXICO 2022-07-01   480.00   960.0
# 17  NMNM128376    RIO ARRIBA  NEW MEXICO 2022-07-01   160.00   320.0
# 19  OKNM128387        GARVIN    OKLAHOMA 2022-07-01    20.00    40.0
# 0    MTM101460        DAWSON     MONTANA 2021-07-01  1193.80  2388.0
# 1    MTM101461        DAWSON     MONTANA 2021-07-01   920.00  1840.0
# 2    MTM101462        DAWSON     MONTANA 2021-07-01   864.95  1730.0
# 3    MTM101463        DAWSON     MONTANA 2021-07-01   803.90  1608.0
# 4    MTM101464        DAWSON     MONTANA 2021-07-01   320.00   640.0
# 5    MTM101465        DAWSON     MONTANA 2021-07-01   318.07   638.0
# 6    MTM101471        DAWSON     MONTANA 2021-07-01  1600.00  3200.0
# 8    MTM109323        FALLON     MONTANA 2027-07-01   160.00   240.0
# 9    MTM109324        FALLON     MONTANA 2027-07-01   120.00   180.0
# 10   MTM109325        FALLON     MONTANA 2027-07-01   160.00   240.0
# 11   MTM109326        FALLON     MONTANA 2027-07-01   280.00   420.0
# 12   MTM109327        FALLON     MONTANA 2027-07-01    40.00    60.0
# 13   MTM109328        FALLON     MONTANA 2027-07-01   200.00   300.0
# 15   MTM109204      GARFIELD     MONTANA 2027-07-01   360.00   540.0
# 16   MTM109205      GARFIELD     MONTANA 2027-07-01   240.00   360.0
# 17   MTM109206      GARFIELD     MONTANA 2027-07-01   600.00   900.0
# 18   MTM109207      GARFIELD     MONTANA 2027-07-01   120.00   180.0
# 20   MTM101475  POWDER RIVER     MONTANA 2021-07-01   960.00  1920.0
# 21   MTM101477  POWDER RIVER     MONTANA 2021-07-01  1049.60  2100.0
# 22   MTM109357  POWDER RIVER     MONTANA 2021-07-01   280.33   421.5
# 23   MTM109359  POWDER RIVER     MONTANA 2021-07-01   600.00   900.0
# 25   MTM101455      RICHLAND     MONTANA 2021-07-01    10.32    22.0
# 26   MTM101456      RICHLAND     MONTANA 2021-07-01     5.88    12.0
# 27   MTM101458      RICHLAND     MONTANA 2021-07-01    40.00    80.0
# 28   MTM101466      RICHLAND     MONTANA 2021-07-01   245.38   492.0
#
#     COUNTY.1  Y/N                                   Mishaun Comments  \
# 0        NaN  NaN                            Keep: 9 years remaining
# 1        NaN  NaN                            Keep: 9 years remaining
# 2      826.5  NaN                            Keep: 9 years remaining
# 4        NaN  NaN                            Keep: 9 years remaining
# 5        NaN  NaN                            Keep: 9 years remaining
# 6     4080.0  NaN                            Keep: 9 years remaining
# 8        NaN  NaN                            Keep: 9 years remaining
# 9        NaN  NaN                            Keep: 9 years remaining
# 10       NaN  NaN                            Keep: 9 years remaining
# 11       NaN  NaN                            Keep: 9 years remaining
# 12    4204.5  NaN                            Keep: 9 years remaining
# 14     361.5  NaN                            Keep: 9 years remaining
# 16       NaN  NaN  Maybe Let Go: No new produciton activity wihti...
# 17    1280.0  NaN  Maybe Let Go: No new produciton activity wihti...
# 19      40.0  NaN  Keep: negligible rental cost - 12 milrs away f...
# 0        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 1        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 2        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 3        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 4        NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 5        NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 6    12044.0  NaN       Maybe Let Go - east of primary fuels acreage
# 8        NaN  NaN                            Keep: 7 years remaining
# 9        NaN  NaN                            Keep: 7 years remaining
# 10       NaN  NaN                            Keep: 7 years remaining
# 11       NaN  NaN                            Keep: 7 years remaining
# 12       NaN  NaN                            Keep: 7 years remaining
# 13    1440.0  NaN                            Keep: 7 years remaining
# 15       NaN  NaN                            Keep: 7 years remaining
# 16       NaN  NaN                            Keep: 7 years remaining
# 17       NaN  NaN                            Keep: 7 years remaining
# 18    1980.0  NaN                            Keep: 7 years remaining
# 20       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 21       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 22       NaN  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 23    5341.5  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 25       NaN  NaN  Keep: negligible rental - wells around tract h...
# 26       NaN  NaN  Keep: negligible rental - closeset well near t...
# 27       NaN  NaN   Keep: neglgible rental - no activiity near tract
# 28     606.0  NaN  Maybe Let Go: Latest well to be drilled is 201...
#
#    St. Initials
# 0            MT
# 1            MT
# 2            MT
# 4            MT
# 5            MT
# 6            MT
# 8            MT
# 9            MT
# 10           MT
# 11           MT
# 12           MT
# 14           MT
# 16           NM
# 17           NM
# 19           OK
# 0            MT
# 1            MT
# 2            MT
# 3            MT
# 4            MT
# 5            MT
# 6            MT
# 8            MT
# 9            MT
# 10           MT
# 11           MT
# 12           MT
# 13           MT
# 15           MT
# 16           MT
# 17           MT
# 18           MT
# 20           MT
# 21           MT
# 22           MT
# 23           MT
# 25           MT
# 26           MT
# 27           MT
# 28           MT

# %%
#Creating Column with DI Counties Format Name
RentalList["DI Counties"] = RentalList["COUNTY"] + " (" + RentalList["St. Initials"] + ")"

# %%
RentalList
# Out:
#      LEASE NO.        COUNTY       STATE EXPIRATION    ACRES  RENTAL  \
# 0    MTM110982        BLAINE     MONTANA 2029-07-01    40.00    60.0
# 1    MTM110983        BLAINE     MONTANA 2029-07-01    80.00   120.0
# 2    MTM110985        BLAINE     MONTANA 2029-07-01   430.50   646.5
# 4    MTM111016        DAWSON     MONTANA 2029-07-01   160.00   240.0
# 5    MTM111017        DAWSON     MONTANA 2029-07-01   480.00   720.0
# 6    MTM111022        DAWSON     MONTANA 2029-07-01  2080.00  3120.0
# 8    MTM110971   MUSSELSHELL     MONTANA 2029-07-01   338.59   508.5
# 9    MTM110972   MUSSELSHELL     MONTANA 2029-07-01   770.53  1156.5
# 10   MTM110973   MUSSELSHELL     MONTANA 2029-07-01   240.00   360.0
# 11   MTM110974   MUSSELSHELL     MONTANA 2029-07-01  1124.09  1687.5
# 12   MTM110975   MUSSELSHELL     MONTANA 2029-07-01   327.08   492.0
# 14   MTM110986         TOOLE     MONTANA 2029-07-01   240.92   361.5
# 16  NMNM128371    RIO ARRIBA  NEW MEXICO 2022-07-01   480.00   960.0
# 17  NMNM128376    RIO ARRIBA  NEW MEXICO 2022-07-01   160.00   320.0
# 19  OKNM128387        GARVIN    OKLAHOMA 2022-07-01    20.00    40.0
# 0    MTM101460        DAWSON     MONTANA 2021-07-01  1193.80  2388.0
# 1    MTM101461        DAWSON     MONTANA 2021-07-01   920.00  1840.0
# 2    MTM101462        DAWSON     MONTANA 2021-07-01   864.95  1730.0
# 3    MTM101463        DAWSON     MONTANA 2021-07-01   803.90  1608.0
# 4    MTM101464        DAWSON     MONTANA 2021-07-01   320.00   640.0
# 5    MTM101465        DAWSON     MONTANA 2021-07-01   318.07   638.0
# 6    MTM101471        DAWSON     MONTANA 2021-07-01  1600.00  3200.0
# 8    MTM109323        FALLON     MONTANA 2027-07-01   160.00   240.0
# 9    MTM109324        FALLON     MONTANA 2027-07-01   120.00   180.0
# 10   MTM109325        FALLON     MONTANA 2027-07-01   160.00   240.0
# 11   MTM109326        FALLON     MONTANA 2027-07-01   280.00   420.0
# 12   MTM109327        FALLON     MONTANA 2027-07-01    40.00    60.0
# 13   MTM109328        FALLON     MONTANA 2027-07-01   200.00   300.0
# 15   MTM109204      GARFIELD     MONTANA 2027-07-01   360.00   540.0
# 16   MTM109205      GARFIELD     MONTANA 2027-07-01   240.00   360.0
# 17   MTM109206      GARFIELD     MONTANA 2027-07-01   600.00   900.0
# 18   MTM109207      GARFIELD     MONTANA 2027-07-01   120.00   180.0
# 20   MTM101475  POWDER RIVER     MONTANA 2021-07-01   960.00  1920.0
# 21   MTM101477  POWDER RIVER     MONTANA 2021-07-01  1049.60  2100.0
# 22   MTM109357  POWDER RIVER     MONTANA 2021-07-01   280.33   421.5
# 23   MTM109359  POWDER RIVER     MONTANA 2021-07-01   600.00   900.0
# 25   MTM101455      RICHLAND     MONTANA 2021-07-01    10.32    22.0
# 26   MTM101456      RICHLAND     MONTANA 2021-07-01     5.88    12.0
# 27   MTM101458      RICHLAND     MONTANA 2021-07-01    40.00    80.0
# 28   MTM101466      RICHLAND     MONTANA 2021-07-01   245.38   492.0
#
#     COUNTY.1  Y/N                                   Mishaun Comments  \
# 0        NaN  NaN                            Keep: 9 years remaining
# 1        NaN  NaN                            Keep: 9 years remaining
# 2      826.5  NaN                            Keep: 9 years remaining
# 4        NaN  NaN                            Keep: 9 years remaining
# 5        NaN  NaN                            Keep: 9 years remaining
# 6     4080.0  NaN                            Keep: 9 years remaining
# 8        NaN  NaN                            Keep: 9 years remaining
# 9        NaN  NaN                            Keep: 9 years remaining
# 10       NaN  NaN                            Keep: 9 years remaining
# 11       NaN  NaN                            Keep: 9 years remaining
# 12    4204.5  NaN                            Keep: 9 years remaining
# 14     361.5  NaN                            Keep: 9 years remaining
# 16       NaN  NaN  Maybe Let Go: No new produciton activity wihti...
# 17    1280.0  NaN  Maybe Let Go: No new produciton activity wihti...
# 19      40.0  NaN  Keep: negligible rental cost - 12 milrs away f...
# 0        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 1        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 2        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 3        NaN  NaN       Keep: In the middle of Primary Fuels Acreage
# 4        NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 5        NaN  NaN  Consider Letting Go: Northern Part of Dawson -...
# 6    12044.0  NaN       Maybe Let Go - east of primary fuels acreage
# 8        NaN  NaN                            Keep: 7 years remaining
# 9        NaN  NaN                            Keep: 7 years remaining
# 10       NaN  NaN                            Keep: 7 years remaining
# 11       NaN  NaN                            Keep: 7 years remaining
# 12       NaN  NaN                            Keep: 7 years remaining
# 13    1440.0  NaN                            Keep: 7 years remaining
# 15       NaN  NaN                            Keep: 7 years remaining
# 16       NaN  NaN                            Keep: 7 years remaining
# 17       NaN  NaN                            Keep: 7 years remaining
# 18    1980.0  NaN                            Keep: 7 years remaining
# 20       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 21       NaN  NaN  Consider Letting Go: All Dry holes around 8 mi...
# 22       NaN  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 23    5341.5  NaN  Keep:  Stephens prod approved permit 1 mi west...
# 25       NaN  NaN  Keep: negligible rental - wells around tract h...
# 26       NaN  NaN  Keep: negligible rental - closeset well near t...
# 27       NaN  NaN   Keep: neglgible rental - no activiity near tract
# 28     606.0  NaN  Maybe Let Go: Latest well to be drilled is 201...
#
#    St. Initials        DI Counties
# 0            MT        BLAINE (MT)
# 1            MT        BLAINE (MT)
# 2            MT        BLAINE (MT)
# 4            MT        DAWSON (MT)
# 5            MT        DAWSON (MT)
# 6            MT        DAWSON (MT)
# 8            MT   MUSSELSHELL (MT)
# 9            MT   MUSSELSHELL (MT)
# 10           MT   MUSSELSHELL (MT)
# 11           MT   MUSSELSHELL (MT)
# 12           MT   MUSSELSHELL (MT)
# 14           MT         TOOLE (MT)
# 16           NM    RIO ARRIBA (NM)
# 17           NM    RIO ARRIBA (NM)
# 19           OK        GARVIN (OK)
# 0            MT        DAWSON (MT)
# 1            MT        DAWSON (MT)
# 2            MT        DAWSON (MT)
# 3            MT        DAWSON (MT)
# 4            MT        DAWSON (MT)
# 5            MT        DAWSON (MT)
# 6            MT        DAWSON (MT)
# 8            MT        FALLON (MT)
# 9            MT        FALLON (MT)
# 10           MT        FALLON (MT)
# 11           MT        FALLON (MT)
# 12           MT        FALLON (MT)
# 13           MT        FALLON (MT)
# 15           MT      GARFIELD (MT)
# 16           MT      GARFIELD (MT)
# 17           MT      GARFIELD (MT)
# 18           MT      GARFIELD (MT)
# 20           MT  POWDER RIVER (MT)
# 21           MT  POWDER RIVER (MT)
# 22           MT  POWDER RIVER (MT)
# 23           MT  POWDER RIVER (MT)
# 25           MT      RICHLAND (MT)
# 26           MT      RICHLAND (MT)
# 27           MT      RICHLAND (MT)
# 28           MT      RICHLAND (MT)

# %%
#output for DI counties - copy and paste into DI
for i in RentalList["DI Counties"].drop_duplicates():
    print(i)
# Out:
# BLAINE (MT)
# DAWSON (MT)
# MUSSELSHELL (MT)
# TOOLE (MT)
# RIO ARRIBA (NM)
# GARVIN (OK)
# FALLON (MT)
# GARFIELD (MT)
# POWDER RIVER (MT)
# RICHLAND (MT)
