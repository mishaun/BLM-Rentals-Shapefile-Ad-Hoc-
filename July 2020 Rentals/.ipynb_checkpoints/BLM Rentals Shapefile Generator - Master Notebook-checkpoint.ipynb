# %%
import pandas as pd
import geopandas as gpd

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
RentalList = pd.read_excel("BLM Rents July 2020.xlsx", header = 4, usecols = 8)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/io/excel.py:527: FutureWarning: Passing in an integer for `usecols` has been deprecated. Please pass in a list of int from 0 to `usecols` inclusive instead.
#   usecols = _maybe_convert_usecols(usecols)

# %%
RentalList
# Out:
#      LEASE NO.       COUNTY       STATE EXPIRATION    ACRES   RENTAL  \
# 0    MTM110982       BLAINE     MONTANA 2029-07-01    40.00     60.0
# 1    MTM110983       BLAINE     MONTANA 2029-07-01    80.00    120.0
# 2    MTM110985       BLAINE     MONTANA 2029-07-01   430.50    646.5
# 3          NaN          NaN         NaN        NaT      NaN      NaN
# 4    MTM111016       DAWSON     MONTANA 2029-07-01   160.00    240.0
# 5    MTM111017       DAWSON     MONTANA 2029-07-01   480.00    720.0
# 6    MTM111022       DAWSON     MONTANA 2029-07-01  2080.00   3120.0
# 7          NaN          NaN         NaN        NaT      NaN      NaN
# 8    MTM110971  MUSSELSHELL     MONTANA 2029-07-01   338.59    508.5
# 9    MTM110972  MUSSELSHELL     MONTANA 2029-07-01   770.53   1156.5
# 10   MTM110973  MUSSELSHELL     MONTANA 2029-07-01   240.00    360.0
# 11   MTM110974  MUSSELSHELL     MONTANA 2029-07-01  1124.09   1687.5
# 12   MTM110975  MUSSELSHELL     MONTANA 2029-07-01   327.08    492.0
# 13         NaN          NaN         NaN        NaT      NaN      NaN
# 14   MTM110986        TOOLE     MONTANA 2029-07-01   240.92    361.5
# 15         NaN          NaN         NaN        NaT      NaN      NaN
# 16  NMNM128371   RIO ARRIBA  NEW MEXICO 2022-07-01   480.00    960.0
# 17  NMNM128376   RIO ARRIBA  NEW MEXICO 2022-07-01   160.00    320.0
# 18         NaN          NaN         NaN        NaT      NaN      NaN
# 19  OKNM128387       GARVIN    OKLAHOMA 2022-07-01    20.00     40.0
# 20         NaN          NaN         NaN        NaT      NaN  10792.5
#
#     COUNTY.1  Y/N  Unnamed: 8
# 0        NaN  NaN         NaN
# 1        NaN  NaN         NaN
# 2      826.5  NaN         NaN
# 3        NaN  NaN         NaN
# 4        NaN  NaN         NaN
# 5        NaN  NaN         NaN
# 6     4080.0  NaN         NaN
# 7        NaN  NaN         NaN
# 8        NaN  NaN         NaN
# 9        NaN  NaN         NaN
# 10       NaN  NaN         NaN
# 11       NaN  NaN         NaN
# 12    4204.5  NaN         NaN
# 13       NaN  NaN         NaN
# 14     361.5  NaN         NaN
# 15       NaN  NaN         NaN
# 16       NaN  NaN         NaN
# 17    1280.0  NaN         NaN
# 18       NaN  NaN         NaN
# 19      40.0  NaN         NaN
# 20   10752.5  NaN         NaN

# %%
#dropping blank rows from dataframe using "all"
RentalList.dropna(how = 'all', inplace = True)

# %%
RentalList
# Out:
#      LEASE NO.       COUNTY       STATE EXPIRATION    ACRES   RENTAL  \
# 0    MTM110982       BLAINE     MONTANA 2029-07-01    40.00     60.0
# 1    MTM110983       BLAINE     MONTANA 2029-07-01    80.00    120.0
# 2    MTM110985       BLAINE     MONTANA 2029-07-01   430.50    646.5
# 4    MTM111016       DAWSON     MONTANA 2029-07-01   160.00    240.0
# 5    MTM111017       DAWSON     MONTANA 2029-07-01   480.00    720.0
# 6    MTM111022       DAWSON     MONTANA 2029-07-01  2080.00   3120.0
# 8    MTM110971  MUSSELSHELL     MONTANA 2029-07-01   338.59    508.5
# 9    MTM110972  MUSSELSHELL     MONTANA 2029-07-01   770.53   1156.5
# 10   MTM110973  MUSSELSHELL     MONTANA 2029-07-01   240.00    360.0
# 11   MTM110974  MUSSELSHELL     MONTANA 2029-07-01  1124.09   1687.5
# 12   MTM110975  MUSSELSHELL     MONTANA 2029-07-01   327.08    492.0
# 14   MTM110986        TOOLE     MONTANA 2029-07-01   240.92    361.5
# 16  NMNM128371   RIO ARRIBA  NEW MEXICO 2022-07-01   480.00    960.0
# 17  NMNM128376   RIO ARRIBA  NEW MEXICO 2022-07-01   160.00    320.0
# 19  OKNM128387       GARVIN    OKLAHOMA 2022-07-01    20.00     40.0
# 20         NaN          NaN         NaN        NaT      NaN  10792.5
#
#     COUNTY.1  Y/N  Unnamed: 8
# 0        NaN  NaN         NaN
# 1        NaN  NaN         NaN
# 2      826.5  NaN         NaN
# 4        NaN  NaN         NaN
# 5        NaN  NaN         NaN
# 6     4080.0  NaN         NaN
# 8        NaN  NaN         NaN
# 9        NaN  NaN         NaN
# 10       NaN  NaN         NaN
# 11       NaN  NaN         NaN
# 12    4204.5  NaN         NaN
# 14     361.5  NaN         NaN
# 16       NaN  NaN         NaN
# 17    1280.0  NaN         NaN
# 19      40.0  NaN         NaN
# 20   10752.5  NaN         NaN

# %%
SerialNumbers = RentalList.loc[:,"LEASE NO."]

# %%
SerialNumbers.dropna(inplace = True)

# %%
SerialNumbers
# Out:
# 0      MTM110982
# 1      MTM110983
# 2      MTM110985
# 4      MTM111016
# 5      MTM111017
# 6      MTM111022
# 8      MTM110971
# 9      MTM110972
# 10     MTM110973
# 11     MTM110974
# 12     MTM110975
# 14     MTM110986
# 16    NMNM128371
# 17    NMNM128376
# 19    OKNM128387
# Name: LEASE NO., dtype: object

# %%
shapefile = gpd.read_file("zip://Master Shapefile 4-2-20.zip")

# %%
shapefile.columns
# Out:
# Index(['OBJECTID_1', 'OBJECTID_2', 'OBJECTID', 'LEASE_NO', 'EFFECTIVE',
#        'EXPIRATION', 'TOTAL_PAID', 'ACRES', 'COUNTY', 'ST', 'Ownership',
#        'Shape_Leng', 'GeneralLoc', 'Due_Year', 'DUE_DATE', 'NO__OF_ACR',
#        'HYPERLINK', 'Comments', 'Shape_Le_1', 'Shape_Le_2', 'Shape_Area',
#        'geometry'],
#       dtype='object')

# %%
shapefile["LEASE_NO"]
# Out:
# 0            NDM101156
# 1            NDM101159
# 2            NDM101160
# 3            NDM101164
# 4            NDM101166
# 5            NDM101169
# 6            NDM101172
# 7            NDM101173
# 8            NDM101180
# 9            MTM101455
# 10           MTM101456
# 11           MTM101458
# 12           MTM101464
# 13           MTM101465
# 14           MTM101475
# 15           MTM101477
# 16           NDM101479
# 17           NDM102132
# 18           NDM102136
# 19           NDM102130
# 20           SDM102222
# 21           SDM102219
# 22           SDM102226
# 23           SDM102664
# 24           SDM103746
# 25           SDM103748
# 26           SDM103750
# 27           SDM103751
# 28           SDM103758
# 29           SDM103761
#              ...
# 1439        NMNM139876
# 1440        NMNM139877
# 1441        NMNM139878
# 1442        NMNM139879
# 1443        NMNM140301
# 1444        NMNM140302
# 1445        KSNM140298
# 1446    WY2020-03-6024
# 1447    WY2020-03-6183
# 1448    WY2020-03-6229
# 1449    WY2020-03-6230
# 1450    WY2020-03-6231
# 1451    WY2020-03-6264
# 1452    WY2020-03-6317
# 1453    WY2020-03-6321
# 1454    WY2020-03-6324
# 1455    WY2020-03-6331
# 1456    WY2020-03-6333
# 1457    WY2020-03-6335
# 1458    WY2020-03-6342
# 1459    WY2020-03-6358
# 1460    WY2020-03-6398
# 1461    WY2020-03-6399
# 1462    WY2020-03-6400
# 1463    WY2020-03-6401
# 1464    WY2020-03-6402
# 1465    WY2020-03-6403
# 1466    WY2020-03-6655
# 1467    WY2020-03-6601
# 1468    WY2020-03-6607
# Name: LEASE_NO, Length: 1469, dtype: object

# %%
RentalShapeFile = shapefile.loc[shapefile["LEASE_NO"].isin(SerialNumbers)]

# %%
RentalShapeFile["LEASE_NO"].count()
SerialNumbers.count()
# Out:
# 15
# 15

# %%
#mismatching - most likely due to mismatching serial number text

# %%
testSerial = SerialNumbers.loc[146]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 146
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-bb9634c5bd84> in <module>
# ----> 1 testSerial = SerialNumbers.loc[146]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     135             # but will fail when the index is not present
#     136             # see GH5667
# --> 137             return self.obj._xs(label, axis=axis)
#     138         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     139             raise IndexingError('no slices here, handle elsewhere')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 146

# %%
testSerial
re.findall('[\w]+', testSerial)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-ec66e63d367b> in <module>
# ----> 1 testSerial
#       2 re.findall('[\w]+', testSerial)[0]
#
# NameError: name 'testSerial' is not defined

# %%
#creating function to run on a pandas series to clean up mistakenly placed special chars at end of serial number on rental spreadsheet
def replaceSpecialChars(serial):
    cleanedSerial = re.findall('[\w]+', serial)[0]
    return cleanedSerial

# %%
CleanedSerials = SerialNumbers.apply(lambda x: replaceSpecialChars(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-0cc24d3867cb> in <module>
# ----> 1 CleanedSerials = SerialNumbers.apply(lambda x: replaceSpecialChars(x))
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-23-0cc24d3867cb> in <lambda>(x)
# ----> 1 CleanedSerials = SerialNumbers.apply(lambda x: replaceSpecialChars(x))
#
# <ipython-input-22-8b1dbe6595b1> in replaceSpecialChars(serial)
#       1 #creating function to run on a pandas series to clean up mistakenly placed special chars at end of serial number on rental spreadsheet
#       2 def replaceSpecialChars(serial):
# ----> 3     cleanedSerial = re.findall('[\w]+', serial)[0]
#       4     return cleanedSerial
#
# NameError: name 're' is not defined

# %%
RentalShapeFile = shapefile.loc[shapefile["LEASE_NO"].isin(CleanedSerials)]

# %%
RentalShapeFile["LEASE_NO"].count()
SerialNumbers.count()
# Out:
# 151
# 151

# %%
RentalShapeFile.to_file("May 2020 - Rental Tracts.shp")

# %%
states = {
        'AK': 'Alaska',
        'AL': 'Alabama',
        'AR': 'Arkansas',
        'AS': 'American Samoa',
        'AZ': 'Arizona',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DC': 'District of Columbia',
        'DE': 'Delaware',
        'FL': 'Florida',
        'GA': 'Georgia',
        'GU': 'Guam',
        'HI': 'Hawaii',
        'IA': 'Iowa',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'MA': 'Massachusetts',
        'MD': 'Maryland',
        'ME': 'Maine',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MO': 'Missouri',
        'MP': 'Northern Mariana Islands',
        'MS': 'Mississippi',
        'MT': 'Montana',
        'NA': 'National',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'NE': 'Nebraska',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NV': 'Nevada',
        'NY': 'New York',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'PR': 'Puerto Rico',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VA': 'Virginia',
        'VI': 'Virgin Islands',
        'VT': 'Vermont',
        'WA': 'Washington',
        'WI': 'Wisconsin',
        'WV': 'West Virginia',
        'WY': 'Wyoming'
}

# %%
#inversing dictionary
statetoInits = {v: k for k, v in states.items()}

# %%
RentalList.info()
RentalList["STATE"] = RentalList["STATE"].astype(str)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 0 to 177
# Data columns (total 9 columns):
# LEASE NO.     151 non-null object
# COUNTY        151 non-null object
# STATE         151 non-null object
# EXPIRATION    151 non-null datetime64[ns]
# ACRES         151 non-null float64
# RENTAL        152 non-null float64
# COUNTY.1      28 non-null float64
# Y/N           0 non-null float64
# Unnamed: 8    0 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(3)
# memory usage: 11.9+ KB

# %%
RentalList["St. Initials"] = RentalList["STATE"].apply(lambda x: x.title()).map(statetoInits)

# %%
RentalList
# Out:
#        LEASE NO.     COUNTY        STATE EXPIRATION     ACRES    RENTAL  \
# 0      ALES56636       BIBB      ALABAMA 2021-05-01   734.120    1470.0
# 1      ALES56637       BIBB      ALABAMA 2021-05-01    34.550      70.0
# 2      ALES57303       BIBB      ALABAMA 2022-05-01  1021.030    2044.0
# 4      ALES57286  COVINGTON      ALABAMA 2022-05-01   320.000     640.0
# 5      ALES57297  COVINGTON      ALABAMA 2022-05-01  1807.540    3616.0
# 6      ALES57298  COVINGTON      ALABAMA 2022-05-01  1805.850    3612.0
# 7      ALES57299  COVINGTON      ALABAMA 2022-05-01  1678.200    3358.0
# 8      ALES57302  COVINGTON      ALABAMA 2022-05-01    90.540     182.0
# 10     ALES57285   ESCAMBIA      ALABAMA 2022-05-01  1664.600    3330.0
# 11     ALES57301   ESCAMBIA      ALABAMA 2022-05-01    80.000     160.0
# 12     ALES57887   ESCAMBIA      ALABAMA 2024-05-01    80.000     160.0
# 14     ALES57284    PICKENS      ALABAMA 2022-05-01   200.000     400.0
# 16     ARES56661    JOHNSON     ARKANSAS 2021-05-01    74.000     148.0
# 17     ARES56662    JOHNSON     ARKANSAS 2021-05-01    75.970     152.0
# 19     ARES56654       POPE     ARKANSAS 2021-05-01    62.455     126.0
# 20     ARES56657       POPE     ARKANSAS 2021-05-01    79.000     158.0
# 21     ARES56658       POPE     ARKANSAS 2021-05-01    40.000      80.0
# 22     ARES56659       POPE     ARKANSAS 2021-05-01    20.000      40.0
# 23     ARES56660       POPE     ARKANSAS 2021-05-01   640.000    1280.0
# 25     ARES56639      SCOTT     ARKANSAS 2021-05-01   558.030    1118.0
# 26     ARES56640      SCOTT     ARKANSAS 2021-05-01    12.400      26.0
# 27     ARES56641      SCOTT     ARKANSAS 2021-05-01   157.470     316.0
# 28     ARES56642      SCOTT     ARKANSAS 2021-05-01    40.000      80.0
# 29     ARES56644      SCOTT     ARKANSAS 2021-05-01   522.170    1046.0
# 30     ARES56645      SCOTT     ARKANSAS 2021-05-01   767.100    1536.0
# 31     ARES56647      SCOTT     ARKANSAS 2021-05-01   358.300     718.0
# 32     ARES56652      SCOTT     ARKANSAS 2021-05-01    80.000     160.0
# 34     ARES57890  VAN BUREN     ARKANSAS 2024-05-01   145.000     290.0
# 6         NaN  NaN         NaN           AL
# 7         NaN  NaN         NaN           AL
# 8     11408.0  NaN         NaN           AL
# 10        NaN  NaN         NaN           AL
# 11        NaN  NaN         NaN           AL
# 12     3650.0  NaN         NaN           AL
# 14      400.0  NaN         NaN           AL
# 16        NaN  NaN         NaN           AR
# 17      300.0  NaN         NaN           AR
# 19        NaN  NaN         NaN           AR
# 20        NaN  NaN         NaN           AR
# 21        NaN  NaN         NaN           AR
# 22        NaN  NaN         NaN           AR
# 23     1684.0  NaN         NaN           AR
# 25        NaN  NaN         NaN           AR
# 26        NaN  NaN         NaN           AR
# 27        NaN  NaN         NaN           AR
# 28        NaN  NaN         NaN           AR
# 29        NaN  NaN         NaN           AR
# 30        NaN  NaN         NaN           AR
# 31        NaN  NaN         NaN           AR
# 32     5000.0  NaN         NaN           AR
# 34        NaN  NaN         NaN           AR
# 35        NaN  NaN         NaN           AR
# 36        NaN  NaN         NaN           AR
# ..        ...  ...         ...          ...
# 144       NaN  NaN         NaN           MS
# 145       NaN  NaN         NaN           MS
# 146   29816.0  NaN         NaN           MS
# 148       NaN  NaN         NaN           MS
# 149    1270.0  NaN         NaN           MS
# 151       NaN  NaN         NaN           MS
# 152       NaN  NaN         NaN           MS
# 153       NaN  NaN         NaN           MS
# 154       NaN  NaN         NaN           MS
# 155       NaN  NaN         NaN           MS
# 156       NaN  NaN         NaN           MS
# 157    8184.0  NaN         NaN           MS
# 159       NaN  NaN         NaN           MS
# 160       NaN  NaN         NaN           MS
# 161       NaN  NaN         NaN           MS
# 162       NaN  NaN         NaN           MS
# 163       NaN  NaN         NaN           MS
# 164       NaN  NaN         NaN           MS
# 165       NaN  NaN         NaN           MS
# 166       NaN  NaN         NaN           MS
# 167       NaN  NaN         NaN           MS
# 168       NaN  NaN         NaN           MS
# 169       NaN  NaN         NaN           MS
# 170       NaN  NaN         NaN           MS
# 171       NaN  NaN         NaN           MS
# 172       NaN  NaN         NaN           MS
# 173       NaN  NaN         NaN           MS
# 174   40756.0  NaN         NaN           MS
# 176    2720.0  NaN         NaN           NM
# 177  267928.0  NaN         NaN          NaN
#
# [152 rows x 10 columns]

# %%
RentalList["DI Counties"] = RentalList["COUNTY"] + " (" + RentalList["St. Initials"] + ")"

# %%
RentalList
# Out:
#        LEASE NO.     COUNTY        STATE EXPIRATION     ACRES    RENTAL  \
# 0      ALES56636       BIBB      ALABAMA 2021-05-01   734.120    1470.0
# 1      ALES56637       BIBB      ALABAMA 2021-05-01    34.550      70.0
# 2      ALES57303       BIBB      ALABAMA 2022-05-01  1021.030    2044.0
# 4      ALES57286  COVINGTON      ALABAMA 2022-05-01   320.000     640.0
# 5      ALES57297  COVINGTON      ALABAMA 2022-05-01  1807.540    3616.0
# 6      ALES57298  COVINGTON      ALABAMA 2022-05-01  1805.850    3612.0
# 7      ALES57299  COVINGTON      ALABAMA 2022-05-01  1678.200    3358.0
# 160    MSES56748      WAYNE  MISSISSIPPI 2021-05-01  1206.110    2414.0
# 161    MSES56749      WAYNE  MISSISSIPPI 2021-05-01   880.550    1762.0
# 162    MSES56751      WAYNE  MISSISSIPPI 2021-05-01   999.450    2000.0
# 163    MSES56752      WAYNE  MISSISSIPPI 2021-05-01   944.250    1890.0
# 164    MSES56755      WAYNE  MISSISSIPPI 2021-05-01  1000.000    2000.0
# 165    MSES56756      WAYNE  MISSISSIPPI 2021-05-01  1217.600    2436.0
# 166    MSES56757      WAYNE  MISSISSIPPI 2021-05-01  1232.410    2466.0
# 167    MSES57359      WAYNE  MISSISSIPPI 2022-05-01  1998.920    3998.0
# 168    MSES57360      WAYNE  MISSISSIPPI 2022-05-01    39.810      80.0
# 169    MSES57361      WAYNE  MISSISSIPPI 2022-05-01  2107.780    4216.0
# 170    MSES57362      WAYNE  MISSISSIPPI 2022-05-01  1925.700    3852.0
# 171    MSES57363      WAYNE  MISSISSIPPI 2022-05-01  1833.650    3668.0
# 172    MSES57364      WAYNE  MISSISSIPPI 2022-05-01  1803.880    3608.0
# 173    MSES57365      WAYNE  MISSISSIPPI 2022-05-01   200.310     402.0
# 174    MSES57366      WAYNE  MISSISSIPPI 2022-05-01  1669.630    3340.0
# 176   NMNM121938     CHAVES   NEW MEXICO 2019-05-01  1359.650    2720.0
# 177          NaN        NaN          nan        NaT       NaN  267928.0
#
#      COUNTY.1  Y/N  Unnamed: 8 St. Initials     DI Counties
# 0         NaN  NaN         NaN           AL       BIBB (AL)
# 1         NaN  NaN         NaN           AL       BIBB (AL)
# 2      3584.0  NaN         NaN           AL       BIBB (AL)
# 4         NaN  NaN         NaN           AL  COVINGTON (AL)
# 5         NaN  NaN         NaN           AL  COVINGTON (AL)
# 6         NaN  NaN         NaN           AL  COVINGTON (AL)
# 7         NaN  NaN         NaN           AL  COVINGTON (AL)
# 8     11408.0  NaN         NaN           AL  COVINGTON (AL)
# 10        NaN  NaN         NaN           AL   ESCAMBIA (AL)
# 11        NaN  NaN         NaN           AL   ESCAMBIA (AL)
# 12     3650.0  NaN         NaN           AL   ESCAMBIA (AL)
# 14      400.0  NaN         NaN           AL    PICKENS (AL)
# 16        NaN  NaN         NaN           AR    JOHNSON (AR)
# 17      300.0  NaN         NaN           AR    JOHNSON (AR)
# 19        NaN  NaN         NaN           AR       POPE (AR)
# 20        NaN  NaN         NaN           AR       POPE (AR)
# 21        NaN  NaN         NaN           AR       POPE (AR)
# 22        NaN  NaN         NaN           AR       POPE (AR)
# 23     1684.0  NaN         NaN           AR       POPE (AR)
# 25        NaN  NaN         NaN           AR      SCOTT (AR)
# 26        NaN  NaN         NaN           AR      SCOTT (AR)
# 27        NaN  NaN         NaN           AR      SCOTT (AR)
# 28        NaN  NaN         NaN           AR      SCOTT (AR)
# 29        NaN  NaN         NaN           AR      SCOTT (AR)
# 30        NaN  NaN         NaN           AR      SCOTT (AR)
# 31        NaN  NaN         NaN           AR      SCOTT (AR)
# 32     5000.0  NaN         NaN           AR      SCOTT (AR)
# 34        NaN  NaN         NaN           AR  VAN BUREN (AR)
# 35        NaN  NaN         NaN           AR  VAN BUREN (AR)
# 36        NaN  NaN         NaN           AR  VAN BUREN (AR)
# ..        ...  ...         ...          ...             ...
# 144       NaN  NaN         NaN           MS      PERRY (MS)
# 145       NaN  NaN         NaN           MS      PERRY (MS)
# 146   29816.0  NaN         NaN           MS      PERRY (MS)
# 148       NaN  NaN         NaN           MS      SCOTT (MS)
# 149    1270.0  NaN         NaN           MS      SCOTT (MS)
# 151       NaN  NaN         NaN           MS      SMITH (MS)
# 152       NaN  NaN         NaN           MS      SMITH (MS)
# 153       NaN  NaN         NaN           MS      SMITH (MS)
# 154       NaN  NaN         NaN           MS      SMITH (MS)
# 155       NaN  NaN         NaN           MS      SMITH (MS)
# 156       NaN  NaN         NaN           MS      SMITH (MS)
# 157    8184.0  NaN         NaN           MS      SMITH (MS)
# 159       NaN  NaN         NaN           MS      WAYNE (MS)
# 160       NaN  NaN         NaN           MS      WAYNE (MS)
# 161       NaN  NaN         NaN           MS      WAYNE (MS)
# 162       NaN  NaN         NaN           MS      WAYNE (MS)
# 163       NaN  NaN         NaN           MS      WAYNE (MS)
# 164       NaN  NaN         NaN           MS      WAYNE (MS)
# 165       NaN  NaN         NaN           MS      WAYNE (MS)
# 166       NaN  NaN         NaN           MS      WAYNE (MS)
# 167       NaN  NaN         NaN           MS      WAYNE (MS)
# 168       NaN  NaN         NaN           MS      WAYNE (MS)
# 169       NaN  NaN         NaN           MS      WAYNE (MS)
# 170       NaN  NaN         NaN           MS      WAYNE (MS)
# 171       NaN  NaN         NaN           MS      WAYNE (MS)
# 172       NaN  NaN         NaN           MS      WAYNE (MS)
# 173       NaN  NaN         NaN           MS      WAYNE (MS)
# 174   40756.0  NaN         NaN           MS      WAYNE (MS)
# 176    2720.0  NaN         NaN           NM     CHAVES (NM)
# 177  267928.0  NaN         NaN          NaN             NaN
#
# [152 rows x 11 columns]

# %%
for i in RentalList["DI Counties"].drop_duplicates():
    print(i)
# Out:
# BIBB (AL)
# COVINGTON (AL)
# ESCAMBIA (AL)
# PICKENS (AL)
# JOHNSON (AR)
# POPE (AR)
# SCOTT (AR)
# VAN BUREN (AR)
# MACCREARY (KY)
# WHITLEY (KY)
# CADDO PARISH (LA)
# CALDWELL PARISH (LA)
# CLAIBORNE (LA)
# GRANT PARISH (LA)
# NATCHITOCHES PARISH (LA)
# SABINE PARISH (LA)
# WEBSTER PARISH (LA)
# WINN PARISH (LA)
# MASON (MI)
# FORREST (MS)
# FRANKLIN (MS)
# PEARL RIVER (MS)
# PERRY (MS)
# SCOTT (MS)
# SMITH (MS)
# WAYNE (MS)
# CHAVES (NM)
# nan
